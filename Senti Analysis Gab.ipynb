# %%
import gensim
import pandas as pd
import os

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Carlo\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
rootdir = "data"
positive_words = []
negative_words = []
neutral_words = []

for directories, subdirs, files in os.walk(rootdir):
    if (os.path.split(directories)[1] == '1' or os.path.split(directories)[1] == '2' or os.path.split(directories)[1] == '3' or os.path.split(directories)[1] == '4'):
        for filename in files:
            if (filename == 'positive.txt'):
                with open(os.path.join(directories, filename)) as f:
                    for line in f:
                        positive_words.append(line.strip())
            if (filename == 'negative.txt'):
                with open(os.path.join(directories, filename)) as f:
                    for line in f:
                        negative_words.append(line.strip())
            if (filename == 'neutral.txt'):
                with open(os.path.join(directories, filename), encoding='latin-1') as f:
                    for line in f:
                        neutral_words.append(line.strip())

# %%
df = pd.read_csv('data/posts_data.csv')
data = df['Body']
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)

# %%
text_data = []

for line in data:
    tokens = gensim.utils.simple_preprocess(line)
    
    tokens = [word for word in tokens if len(word) > 2]
    
    text_data.append(tokens)
#     print('Original Sentence:', line)
    print('Tokens:', tokens)
    print()
# Out:
# Tokens: ['does', 'anyone', 'get', 'blisters', 'their', 'feet', 'from', 'walking', 'much', 'around', 'school']
#
# Tokens: ['been', 'few', 'months', 'since', 'that', 'whole', 'sexual', 'harassment', 'scandal', 'rocked', 'ateneo', 'the', 'silence', 'deafening', 'some', 'the', 'profs', 'who', 'have', 'been', 'vocal', 'about', 'issues', 'like', 'martial', 'law', 'etc', 'never', 'spoke', 'about', 'this', 'particular', 'issue', 'and', 'now', 'they', 'opening', 'about', 'that', 'fucking', 'upsilon', 'scandal', 'like', 'the', 'worst', 'shit', 'ever', 'fuck', 'you', 'hypocrites']
#
# Tokens: ['think', 'the', 'reason', 'why', 'really', 'hate', 'filipino', 'college', 'not', 'because', 'the', 'language', 'but', 'the', 'topics', 'understand', 'filipino', 'was', 'about', 'learning', 'how', 'speak', 'deeper', 'tagalog', 'learning', 'like', 'street', 'tagalog', 'culture', 'anything', 'related', 'our', 'present', 'times', 'instead', 'college', 'filipino', 'least', 'what', 'experienced', 'here', 'for', 'had', 'very', 'unnecessary', 'lack', 'better', 'term', 'useless', 'topics', 'lol', 'filipino', 'learn', 'about', 'girl', 'falling', 'love', 'with', 'nature', 'getting', 'horny', 'learn', 'about', 'the', 'ancient', 'filipinos', 'and', 'their', 'super', 'weird', 'cultures', 'and', 'are', 'required', 'memorize', 'authors', 'books', 'that', 'probably', 'never', 'read', 'again', 'what', 'trying', 'say', 'that', 'these', 'topics', 'are', 'not', 'very', 'applicable', 'our', 'present', 'society', 'sure', 'can', 'understand', 'girl', 'loves', 'nature', 'sure', 'can', 'study', 'about', 'the', 'ancient', 'filipino', 'culture', 'sure', 'can', 'memorize', 'random', 'authors', 'names', 'but', 'the', 'end', 'after', 'graduate', 'sure', 'all', 'these', 'things', 'learned', 'will', 'forgotten', 'simply', 'because', 'they', 'useless', 'not', 'very', 'applicable', 'life', 'talk', 'about', 'authors', 'memorized', 'lol', 'guess', 'thats', 'why', 'people', 'are', 'against', 'the', 'filipino', 'subject', 'not', 'because', 'filipino', 'sucks', 'more', 'because', 'the', 'topics', 'being', 'taught', 'are', 'really', 'useless']
#
# Tokens: ['tangina', 'this', 'obf', 'wifi', 'pure', 'shit', 'all', 'those', 'people', 'who', 'say', 'that', 'there', 'are', 'thousands', 'students', 'here', 'ateneo', 'well', 'guess', 'what', 'paid', 'thousands', 'for', 'internet', 'campus', 'you', 'guys', 'backing', 'the', 'team', 'whatever', 'are', 'just', 'naive', 'they', 'are', 'supposed', 'have', 'enough', 'funds', 'connect', 'and', 'have', 'stable', 'internet', 'everywhere', 'lagi', 'may', 'nagdadala', 'mobile', 'wifi', 'personal', 'hotspot', 'accept', 'nila', 'the', 'school', 'wifi', 'not', 'trustable', 'but', 'that', 'not', 'fair', 'lol', 'they', 'were', 'taken', 'advantage', 'they', 'paid', 'have', 'internet', 'and', 'never', 'got', 'what', 'they', 'paid', 'for', 'instead', 'they', 'had', 'pay', 'even', 'more', 'hotspot', 'mobile', 'wifi', 'have', 'wifi', 'edi', 'sana', 'tanggalin', 'nlg', 'internet', 'school', 'tuition', 'noh']
#
# Tokens: ['sometimes', 'mood', 'mood', 'putangina', 'but', 'current', 'mood', 'putanginaaaaaa', 'ugh', 'life', 'fuck', 'have', 'acads', 'pursue']
#
# Tokens: ['the', 'marisol', 'announcements', 'really', 'need', 'more', 'thought', 'and', 'effort', 'put', 'into', 'them', 'honestly', 'feel', 'more', 'discouraged', 'watch', 'because', 'how', 'hastily', 'prepared', 'them', 'sound']
#
# Tokens: ['https', 'tonite', 'abante', 'com', 'ateneo', 'student', 'ginulpi', 'hinolda', 'tag', 'away']
#
# Tokens: ['grabe', 'ang', 'lubak', 'covered', 'courts', 'wtf']
#
# Tokens: ['free', 'falling', 'and', 'not', 'sure', 'you', 'there', 'catch', 'the', 'bottom']
#
# Tokens: ['thought', 'that', 'the', 'east', 'carpark', 'strictly', 'for', 'students', 'only', 'why', 'there', 'white', 'innova', 'parked', 'beside', 'with', 'driver']
#
# Tokens: ['why', 'anti', 'poor', 'considered', 'bad', 'word', 'politics', 'poor', 'people', 'squat', 'your', 'land', 'you', 'have', 'legal', 'right', 'evict', 'them', 'even', 'though', 'anti', 'poor', 'poor', 'people', 'peddle', 'goods', 'and', 'throw', 'trash', 'the', 'sidewalks', 'you', 'have', 'the', 'authority', 'remove', 'them', 'even', 'though', 'anti', 'poor', 'poor', 'people', 'build', 'squatter', 'colonies', 'along', 'esteros', 'and', 'waterways', 'you', 'have', 'the', 'moral', 'obligation', 'relocate', 'them', 'even', 'though', 'anti', 'poor', 'just', 'because', 'something', 'anti', 'poor', 'doesn', 'automatically', 'mean', 'bad', 'fact', 'some', 'anti', 'poor', 'policies', 'may', 'good', 'for', 'society']
#
# Tokens: ['why', 'none', 'the', 'sockets', 'the', 'old', 'lib', 'work', 'hsjsgfdhkfjklhs']
#
# Tokens: ['stop', 'using', 'mental', 'health', 'complain', 'about', 'school', 'difficulty', 'real', 'life', 'much', 'harder']
#
# Tokens: ['admufreedomwall', 'and', 'admufreedomwall', 'feel', 'you', 'guys', 'oldie', 'the', 'org', 'assume', 'you', 'are', 'referring', 'and', 'honest', 'only', 'remained', 'member', 'because', 'still', 'somehow', 'love', 'work', 'and', 'still', 'have', 'very', 'very', 'good', 'friends', 'the', 'org', 'yes', 'they', 'are', 'very', 'cliquish', 'what', 'completely', 'sucks', 'that', 'there', 'sense', 'coldness', 'between', 'the', 'cast', 'and', 'the', 'production', 'teams', 'hell', 'cast', 'members', 'don', 'even', 'say', 'you', 'when', 'you', 'say', 'them', 'the', 'theater', 'for', 'fuck', 'sake', 'one', 'time', 'after', 'just', 'finished', 'doing', 'the', 'show', 'for', 'lights', 'stepped', 'out', 'and', 'they', 'told', 'thank', 'you', 'for', 'watching', 'were', 'part', 'the', 'audience', 'they', 'didn', 'even', 'know', 'been', 'there', 'for', 'literally', 'almost', 'every', 'show', 'this', 'was', 'done', 'times', 'fucking', 'times', 'like', 'holy', 'shit', 'niyo', 'ako', 'kilala', 'something', 'try', 'say', 'you', 'people', 'every', 'fucking', 'time', 'all', 'the', 'people', 'who', 'defend', 'the', 'org', 'and', 'say', 'just', 'they', 'there', 'for', 'reason', 'this', 'isn', 'simple', 'problem', 'there', 'problem', 'with', 'how', 'the', 'org', 'has', 'been', 'systematically', 'there', 'lot', 'nepotism', 'some', 'people', 'get', 'positions', 'that', 'they', 'don', 'deserve', 'but', 'only', 'get', 'because', 'they', 'friends', 'with', 'the', 'pms', 'for', 'example', 'once', 'applied', 'the', 'part', 'mainstage', 'second', 'semester', 'production', 'prior', 'applying', 'had', 'done', 'org', 'productions', 'productions', 'for', 'another', 'org', 'and', 'even', 'done', 'professional', 'work', 'outside', 'ateneo', 'basically', 'and', 'not', 'boast', 'was', 'the', 'one', 'for', 'the', 'job', 'didn', 'get', 'instead', 'someone', 'who', 'was', 'close', 'with', 'the', 'and', 'whose', 'only', 'experience', 'technicals', 'was', 'working', 'set', 'props', 'got', 'the', 'job', 'was', 'incredibly', 'frustrating', 'that', 'being', 'said', 'the', 'two', 'newbies', 'who', 'have', 'spoken', 'out', 'implore', 'you', 'stay', 'not', 'because', 'the', 'people', 'stay', 'for', 'the', 'craft', 'can', 'denied', 'that', 'said', 'org', 'still', 'has', 'great', 'productions', 'despite', 'lot', 'backstage', 'frustration', 'and', 'the', 'performers', 'are', 'still', 'among', 'the', 'best', 'the', 'school', 'and', 'even', 'the', 'philippines', 'love', 'your', 'work', 'doesn', 'mean', 'you', 'have', 'love', 'the', 'people', 'along', 'the', 'way', 'screw', 'them']
#
# Tokens: ['dreamt', 'that', 'this', 'girl', 'from', 'org', 'and', 'were', 'making', 'momol', 'and', 'weird', 'and', 'don', 'want', 'like', 'her', 'that', 'way', 'cause', 'she', 'the', 'first', 'real', 'friend', 'had', 'that', 'org']
#
# Tokens: ['what', 'the', 'least', 'painful', 'way', 'kill', 'yourself', 'wanna', 'die', 'but', 'like', 'just', 'dont', 'want', 'inflict', 'too', 'much', 'physical', 'pain', 'myself', 'existing', 'just', 'too', 'much', 'nowadays', 'help', 'bro', 'out', 'giving', 'suggestions', 'hehe']
#
# Tokens: ['okay', 'haven', 'had', 'any', 'sleep', 'and', 'was', 'wandering', 'around', 'ateneo', 'playing', 'pokemon', 'when', 'was', 'participating', 'raid', 'with', 'someone', 'else', 'finished', 'the', 'raid', 'and', 'they', 'seemed', 'super', 'nice', 'and', 'they', 'tried', 'talk', 'but', 'was', 'super', 'zoned', 'out', 'and', 'was', 'super', 'slow', 'listening', 'sorry', 'hope', 'didn', 'offend', 'but', 'thank', 'you', 'for', 'helping', 'get', 'the', 'mareep', 'and', 'applied', 'join', 'the', 'group', 'you', 'asked', 'think']
#
# Tokens: ['any', 'tips', 'how', 'make', 'landi', 'with', 'girl', 'you', 'not', 'close', 'with', 'but', 'you', 'want']
#
# Tokens: ['admufreedomwall', 'heard', 'that', 'quite', 'number', 'them', 'graduated', 'from', 'ahs']
#
# Tokens: ['which', 'better', 'dell', 'xps', 'macbook', 'pro', 'need', 'them', 'opinions']
#
# Tokens: ['want', 'love']
#
# Tokens: ['when', 'you', 'just', 'wanna', 'get', 'the', 'sakamura', 'stall', 'gonz', 'but', 'the', 'line', 'sutra', 'long', 'abot', 'hanggang', 'hunger', 'buster', 'and', 'you', 'can', 'get', 'through']
#
# Tokens: ['were', 'living', 'peacefully', 'the', 'beginning', 'until', 'people', 'from', 'outside', 'these', 'islands', 'came', 'and', 'fucked', 'many', 'ways', 'ironic', 'though', 'the', 'end', 'all', 'wouldn', 'foreigners', 'but', 'our', 'very', 'own', 'brother', 'fellow', 'filipino', 'who', 'would', 'screw', 'over', 'and', 'sell', 'out']
#
# Tokens: ['let', 'just', 'remember', 'that', 'there', 'was', 'point', 'history', 'where', 'were', 'privileged', 'have', 'something', 'beautiful', 'nation', 'land', 'could', 'call', 'home', 'years', 'from', 'now', 'our', 'grandkids', 'wouldn', 'have', 'the', 'same', 'privilege', 'this', 'archipelago', 'will', 'province', 'another', 'state', 'but', 'this', 'archipelago', 'the', 'philippines', 'will', 'cease', 'exist', 'every', 'concept', 'notion', 'filipino', 'will', 'cease', 'exist', 'when', 'your', 'grandchildren', 'you', 'they', 'will', 'ask', 'you', 'what', 'was', 'like', 'filipino', 'and', 'you', 'will', 'tell', 'them', 'your', 'stories', 'with', 'tears', 'your', 'eyes', 'knowing', 'that', 'there', 'was', 'moment', 'history', 'where', 'nation', 'called', 'the', 'philippines', 'existed', 'and', 'you', 'were', 'part', 'that', 'history']
#
# Tokens: ['tangina', 'naman', 'kahit', 'winasak', 'ako', 'kahit', 'araw', 'araw', 'akong', 'namamatay', 'dahil', 'kahit', 'ang', 'sakit', 'sakit', 'talaga', 'grabe', 'sobrang', 'lala', 'bakit', 'hindi', 'rin', 'nagbabago', 'pakiramdam', 'para', 'iyo']
#
# Tokens: ['the', 'only', 'atenean', 'natatakot', 'nangyayari', 'inside', 'upd', 'like', 'this', 'guys', 'from', 'downsilon', 'can', 'kill', 'people', 'with', 'guns', 'without', 'anyone', 'noticing', 'them', 'someone', 'please', 'stop', 'those', 'barbaric', 'pigs']
#
# Tokens: ['miss', 'back', 'home', 'bad', 'been', 'restless', 'for', 'the', 'past', 'couple', 'weeks', 'and', 'can', 'wait', 'home', 'been', 'super', 'nervous', 'and', 'fidgety', 'ever', 'since', 'she', 'stopped', 'replying', 'messages', 'often', 'tell', 'myself', 'she', 'busy', 'she', 'studying', 'she', 'with', 'her', 'friends', 'you', 'gotta', 'give', 'her', 'some', 'space', 'man', 'but', 'matter', 'how', 'hard', 'try', 'that', 'annoying', 'thought', 'lingers', 'mind', 'that', 'she', 'isn', 'interested', 'anymore', 'can', 'even', 'tell', 'her', 'how', 'feel', 'because', 'she', 'rarely', 'ever', 'replies', 'and', 'yet', 'tell', 'myself', 'she', 'busy', 'with', 'academics', 'give', 'her', 'space', 'and', 'will', 'all', 'work', 'out', 'the', 'end', 'hope']
#
# Tokens: ['hayss', 'this', 'group']
#
# Tokens: ['take', 'photos', 'the', 'carrie', 'photographer', 'but', 'photography', 'isn', 'allowed', 'daw', 'the', 'theater']
#
# Tokens: ['people', 'trying', 'save', 'endangered', 'species', 'want', 'see', 'the', 'animals', 'fuck']
#
# Tokens: ['what', 'expected', 'from', 'filipino', 'classes', 'great', 'class', 'that', 'focuses', 'filipino', 'culture', 'linguistics', 'history', 'and', 'modern', 'politics', 'educating', 'students', 'with', 'solid', 'information', 'worthy', 'one', 'the', 'top', 'schools', 'the', 'country', 'what', 'got', 'teacher', 'which', 'uses', 'hour', 'rant', 'about', 'that', 'you', 'gotta', 'work', 'work', 'gatorade', 'saying', 'that', 'brainwashing', 'people', 'work', 'minimum', 'wage', 'job', 'then', 'die', 'the', 'capitalist', 'system', 'instead', 'you', 'know', 'just', 'being', 'trying', 'target', 'specific', 'audience', 'athletes', 'that', 'relate', 'the', 'routine', 'training', 'that', 'athletes', 'the', 'video', 'endure']
#
# Tokens: ['should', 'give', 'another', 'chance', 'want', 'too', 'know', 'loves', 'but', 'don', 'know', 'worth', 'anymore', 'huhhuhu']
#
# Tokens: ['favorite', 'pokemon', 'game', 'honestly', 'pokemon', 'snap', 'was', 'weird', 'but', 'they', 'sorta', 'added', 'the', 'concept', 'pokemon', 'sumo']
#
# Tokens: ['always', 'prayed', 'that', 'never', 'get', 'anybody', 'pregnant', 'before', 'got', 'decent', 'job', 'year', 'later', 'found', 'out', 'was', 'gay', 'prayer', 'answered', 'guess']
#
# Tokens: ['admufreedomwall', 'anon', 'used', 'newbie', 'that', 'org', 'too', 'and', 'had', 'the', 'worst', 'experience', 'life', 'felt', 'was', 'working', 'with', 'people', 'with', 'the', 'primary', 'intention', 'receiving', 'attention', 'and', 'high', 'dose', 'fame', 'was', 'disgusting', 'there', 'were', 'good', 'people', 'sure', 'but', 'the', 'whole', 'working', 'environment', 'was', 'terrifying', 'working', 'with', 'them', 'set', 'the', 'mood', 'for', 'freshie', 'life', 'back', 'then', 'and', 'can', 'say', 'dreaded', 'life', 'thankful', 'have', 'gotten', 'out', 'still', 'wish', 'they', 'would', 'change', 'for', 'despite', 'everything', 'remain', 'hopeful', 'for', 'them', 'this', 'year', 'newbies', 'save', 'yourselves', 'you', 'choose', 'stay', 'save', 'the', 'org', 'and', 'change', 'for', 'the', 'better', 'for', 'your', 'craft', 'not', 'for', 'your', 'reputation']
#
# Tokens: ['the', 'only', 'one', 'who', 'not', 'close', 'with', 'block', 'after', 'looking', 'aegis', 'block', 'photoshoots', 'they', 'look', 'close', 'each', 'other']
#
# Tokens: ['wow', 'such', 'strongman', 'leader', 'love', 'jinping']
#
# Tokens: ['admufreedomwall', 'alam', 'yung', 'mas', 'masakit', 'yung', 'kinuwento', 'kaibigan', 'crush', 'naging', 'sila']
#
# Tokens: ['ugly', 'and', 'this', 'makes', 'sad']
#
# Tokens: ['just', 'really', 'really', 'wanted', 'say', 'fuckinnnnng', 'sad', 'and', 'one', 'would', 'ever', 'think', 'the', 'one', 'send', 'this', 'cause', 'everyone', 'thinks', 'always', 'happy']
#
# Tokens: ['empire', 'toppled', 'its', 'enemies', 'can', 'rise', 'again', 'but', 'one', 'that', 'crumbles', 'from', 'within', 'that', 'dead', 'forever', 'helmut', 'zemo', 'civil', 'war']
#
# Tokens: ['oaa', 'ask', 'lang', 'kelan', 'dadating', 'allowance', 'thanks']
#
# Tokens: ['don', 'slam', 'for', 'musical', 'preferences', 'yes', 'diehard', 'rock', 'roll', 'listener', 'who', 'acts', 'rebellious', 'but', 'can', 'you', 'please', 'please', 'please', 'shut', 'the', 'fuck', 'you', 'have', 'nothing', 'nice', 'say', 'about', 'music', 'sorry', 'act', 'really', 'raunchy', 'towards', 'modern', 'pop', 'music', 'times', 'but', 'sometimes', 'all', 'about', 'the', 'substance', 'that', 'the', 'music', 'gives', 'not', 'the', 'popularity', 'and', 'hype', 'that', 'all', 'those', 'whiffle', 'waffles', 'out', 'there', 'try', 'rub', 'our', 'faces', 'with', 'deal', 'with', 'that']
#
# Tokens: ['please', 'subscribe', 'pewdiepie', 'doing', 'part']
#
# Tokens: ['love', 'class', 'much', 'but', 'sometimes', 'just', 'feel', 'like', 'they', 'like', 'vanilla', 'ice', 'cream', 'and', 'friends', 'and', 'small', 'friend', 'group', 'are', 'like', 'the', 'fun', 'flavors', 'like', 'cookies', 'and', 'cream', 'rocky', 'road', 'etc', 'the', 'rest', 'them', 'can', 'just', 'such', 'fucking', 'bore', 'like', 'don', 'hate', 'them', 'just', 'feel', 'like', 'sometimes', 'wanna', 'say', 'something', 'crazy', 'and', 'outlandish', 'but', 'because', 'their', 'sweet', 'vanilla', 'nature', 'they', 'just', 'smile', 'and', 'say', 'fine', 'and', 'pretend', 'never', 'happened', 'right', 'now', 'just', 'trying', 'friends', 'with', 'them', 'because', 'they', 'really', 'are', 'genuine', 'and', 'nice', 'people', 'they', 'can', 'just', 'bland', 'boring', 'and', 'basic', 'most', 'the', 'time']
#
# Tokens: ['was', 'bobo', 'way', 'back', 'ateneo', 'days', 'compared', 'classmates', 'they', 'keep', 'having', 'grades', 'like', 'and', 'and', 'ako', 'naman', 'panay', 'really', 'thought', 'was', 'not', 'gonna', 'graduate', 'pero', 'puta', 'did', 'and', 'now', 'working', 'and', 'job', 'pays', 'great', 'wag', 'kayo', 'susuko', 'guys', 'laging', 'may', 'light', 'the', 'end', 'tunnel', 'kung', 'ano', 'man', 'yan', 'dinadanan']
#
# Tokens: ['anyone', 'know', 'pokemon', 'music', 'from', 'gen', 'gen', 'maybe', 'even', 'gen', 'and']
#
# Tokens: ['happy', 'thanksgiving', 'everyone', 'hope', 'enjoyed', 'your', 'turkey', 'and', 'pies']
#
# Tokens: ['hate', 'fraudulent', 'misleading', 'networking', 'people', 'this', 'post', 'was', 'made', 'warn', 'people', 'about', 'networking', 'and', 'how', 'fraudulent', 'their', 'reps', 'are', 'know', 'not', 'good', 'generalize', 'but', 'there', 'was', 'this', 'brand', 'rhymes', 'with', 'muskeen', 'who', 'invited', 'for', 'meeting', 'about', 'job', 'opening', 'field', 'already', 'skeptical', 'about', 'told', 'them', 'that', 'think', 'about', 'joke', 'for', 'worrying', 'come', 'off', 'impolite', 'say', 'when', 'the', 'day', 'came', 'that', 'followed', 'for', 'confirmation', 'straight', 'asked', 'the', 'person', 'was', 'network', 'marketing', 'event', 'literally', 'said', 'that', 'wasnt', 'believing', 'him', 'went', 'the', 'meeting', 'because', 'trusted', 'him', 'that', 'where', 'made', 'the', 'biggest', 'mistake', 'the', 'speakers', 'the', 'event', 'were', 'going', 'about', 'how', 'network', 'marketing', 'was', 'the', 'best', 'way', 'earn', 'money', 'ugh', 'fuq', 'ive', 'been', 'lied', 'and', 'fell', 'for', 'already', 'laughing', 'myself', 'for', 'falling', 'for', 'this', 'but', 'sharing', 'this', 'experience', 'all', 'cautionary', 'tale', 'avoid', 'people', 'messaging', 'you', 'about', 'business', 'venture', 'business', 'opportunity', 'take', 'everything', 'with', 'grain', 'salt', 'they', 'won', 'tell', 'you', 'what', 'brand', 'they', 'working', 'for', 'don', 'waste', 'more', 'time', 'entertaining', 'these', 'shady', 'people', 'you', 'already', 'think', 'they', 'dodgey', 'trust', 'your', 'gut', 'you', 'can', 'find', 'them', 'the', 'first', 'page', 'google', 'don', 'even', 'think', 'about', 'network', 'marketers', 'pyramid', 'scheme', 'scammers', 'make', 'people', 'the', 'higher', 'wrungs', 'richer', 'they', 'stigmatized', 'for', 'reason', 'all', 'these', 'skincare', 'health', 'pharma', 'things', 'may', 'the', 'bread', 'and', 'butter', 'some', 'but', 'hope', 'these', 'people', 'dont', 'lie', 'people', 'just', 'they', 'can', 'get', 'their', 'way', 'not', 'impolite', 'step', 'away', 'when', 'you', 'realize', 'fraudulent', 'invitation', 'that', 'hours', 'life', 'that', 'won', 'get', 'back', 'how', 'these', 'people', 'sleep']
#
# Tokens: ['angry', 'class', 'for', 'having', 'swear', 'jar']
#
# Tokens: ['almost', 'the', 'end', 'the', 'sem', 'life', 'mood']
#
# Tokens: ['there', 'these', 'group', 'people', 'who', 'will', 'invite', 'you', 'marketing', 'event', 'octagon', 'plaza', 'ortigas', 'but', 'wait', 'people', 'scam', 'because', 'all', 'that', 'making', 'think', 'networking', 'best', 'marketing', 'for', 'the', 'sole', 'intention', 'blinding', 'you', 'sell', 'their', 'products', 'this', 'not', 'some', 'dark', 'capitalist', 'shit', 'pyramid', 'scheme', 'idk', 'what']
#
# Tokens: ['fuck', 'shit', 'bitch', 'gago', 'putangina', 'sorry', 'just', 'letting', 'out', 'swears', 'that', 'can', 'say', 'because', 'class', 'had', 'have', 'the', 'shitty', 'idea', 'having', 'swear', 'jar', 'know', 'for', 'the', 'class', 'funds', 'but', 'would', 'happily', 'donate', 'the', 'class', 'funds', 'can', 'just', 'let', 'out', 'emotions', 'goddammit']
#
# Tokens: ['looking', 'for', 'date', 'lantern', 'parade', 'isko', 'here', 'sisiguraduhin', 'kong', 'hindi', 'malungkot', 'ang', 'pasko', 'sasamahan', 'kitang', 'mag', 'simbang', 'gabi', 'ateneo', 'pwede', 'rin']
#
# Tokens: ['you', 'been', 'good', 'friend', 'who', 'treats', 'well', 'but', 'the', 'thing', 'nothing', 'special', 'you', 'all', 'realized', 'just', 'how', 'you', 'are', 'with', 'everyone', 'but', 'the', 'thing', 'one', 'ever', 'treated', 'like', 'this', 'sorry', 'but', 'can', 'help', 'you', 'special']
#
# Tokens: ['poor', 'guy', 'wasn', 'able', 'his', 'retreat', 'because', 'something', 'stupid', 'and', 'feel', 'like', 'partly', 'responsible', 'because', 'could', 'have', 'done', 'something', 'but', 'didn', 'because', 'was', 'afraid', 'was', 'too', 'far', 'gone', 'but', 'clearly', 'needed', 'someone', 'there', 'for', 'him', 'just', 'hope', 'finds', 'the', 'love', 'needs']
#
# Tokens: ['still', 'have', 'soft', 'spot', 'for', 'you', 'and', 'always', 'going', 'love', 'you', 'but', 'love', 'means', 'making', 'sure', 'the', 'people', 'you', 'care', 'about', 'are', 'happy', 'and', 'the', 'best', 'versions', 'themselves', 'sometimes', 'find', 'myself', 'wishing', 'that', 'the', 'end', 'tayo', 'rin', 'yung', 'magkakatuluyan', 'but', 'whenever', 'see', 'you', 'happy', 'with', 'him', 'just', 'know', 'that', 'have', 'accept', 'that', 'not', 'going', 'happen', 'ang', 'hirap', 'talaga', 'tanggapin', 'that', 'never', 'going', 'enough', 'for', 'you', 'but', 'here', 'what', 'could', 'have', 'been', 'where', 'are', 'now', 'and', 'where']
#
# Tokens: ['omg', 'can', 'also', 'please', 'have', 'this', 'revolutionary', 'actual', 'links', 'tiny', 'meets', 'pickform', 'tiny', 'meets', 'pickmenu']
#
# Tokens: ['believe', 'school', 'has', 'conditioned', 'perfectionists', 'excelling', 'not', 'for', 'the', 'purpose', 'learning', 'and', 'improvement', 'but', 'from', 'the', 'fear', 'failure', 'and', 'inadequacy', 'embedded', 'our', 'brains', 'the', 'smartest', 'guys', 'get', 'rewarded', 'the', 'failures', 'don', 'graduate', 'but', 'aren', 'just', 'students', 'aren', 'robots', 'are', 'people', 'are', 'not', 'limited', 'the', 'things', 'that', 'try', 'put', 'box', 'all', 'have', 'our', 'own', 'form', 'beauty', 'and', 'intelligence', 'and', 'our', 'lives', 'are', 'about', 'using', 'fullest', 'potential', 'not', 'about', 'grades', 'not', 'about', 'what', 'you', 'get', 'but', 'who', 'you', 'become', 'you', 'reading', 'this', 'and', 'you', 'going', 'through', 'tough', 'time', 'these', 'final', 'weeks', 'remember', 'that', 'while', 'you', 'always', 'your', 'best', 'never', 'think', 'that', 'you', 'have', 'something', 'prove', 'anyone', 'that', 'you', 'trying', 'validate', 'something', 'control', 'what', 'you', 'can', 'control', 'existence', 'precedes', 'essence']
#
# Tokens: ['can', 'please', 'stop', 'downplaying', 'other', 'courses', 'management', 'not', 'basic', 'course', 'you', 'have', 'someone', 'calling', 'you', 'out', 'for', 'having', 'mediocre', 'grades', 'but', 'what', 'does', 'card', 'with', 'your', 'happiness', 'what', 'everyone', 'the', 'family', 'smart', 'does', 'that', 'mean', 'have', 'also', 'what', 'much', 'rather', 'active', 'orgs', 'want', 'with', 'our', 'friends', 'can', 'stop', 'judging', 'one', 'another', 'and', 'support', 'each', 'other', 'growth', 'and', 'happiness', 'instead', 'damn']
#
# Tokens: ['charot', 'good', 'for', 'your', 'eyes']
#
# Tokens: ['taong', 'gulang', 'pero', 'isip', 'bata', 'rin']
#
# Tokens: ['heard', 'that', 'the', 'aegis', 'shoot', 'for', 'ica', 'jude', 'and', 'grace', 'are', 'all', 'taking', 'place', 'the', 'same', 'time', 'iso', 'prepare', 'for', 'the', 'chinese', 'invasion']
#
# Tokens: ['mood', 'mood']
#
# Tokens: ['tangina', 'naman']
#
# Tokens: ['normal', 'doubt', 'man', 'kapag', 'may', 'nag', 'notif', 'about', 'grindr', 'and', 'other', 'shit', 'sabi', 'niya', 'hindi', 'daw', 'siya', 'active', 'pero', 'why', 'won', 'delete', 'those', 'fucking', 'apps', 'tapos', 'said', 'kung', 'nag', 'ddoubt', 'ibig', 'sabihin', 'may', 'ginawa', 'kang', 'masama', 'pang', 'hinayupak', 'ung', 'sagot', 'hindi', 'ako', 'bobo', 'para', 'hindi', 'malaman', 'you', 'fucking', 'cheating', 'tapos', 'won', 'change', 'ung', 'bio', 'niya', 'twitter', 'fairview', 'hot', 'body', 'you', 'interested', 'likee', 'potaaaa', 'lng', 'feeling', 'single', 'gago', 'plus', 'ung', 'pinag', 'llike', 'niya', 'tweets', 'puro', 'tite', 'iwww', 'pero', 'wala', 'ako', 'magagawa', 'cheer', 'nlng', 'siya', 'pokpok']
#
# Tokens: ['admufreedomwall', 'crushie', 'sana', 'pansinin', 'nakinjure', 'ako', 'kanina', 'nakita']
#
# Tokens: ['bat', 'wala', 'kong', 'facial', 'hair', 'ampota']
#
# Tokens: ['hello', 'how', 'you', 'leave', 'band']
#
# Tokens: ['tangina', 'naman', 'daming', 'tao', 'naglalandi', 'sakin', 'crushie', 'lang', 'hindi', 'hoy', 'crush', 'umayos', 'naman', 'nyeta', 'kung', 'sino', 'ung', 'gusto', 'lumandi', 'sayo', 'siya', 'talaga', 'ung', 'hindi']
#
# Tokens: ['the', 'philippines', 'becomes', 'province', 'china', 'then', 'technically', 'chinito', 'maybe', 'crush', 'will', 'like']
#
# Tokens: ['what', 'you', 'hypothetically', 'you', 'get', 'crush', 'prof', 'asking', 'for', 'friend', 'confusedfreshie']
#
# Tokens: ['can', 'organize', 'some', 'event', 'where', 'get', 'have', 'the', 'consciousness', 'examen', 'minutes', 'tops', 'the', 'chapel', 'some', 'other', 'place', 'every', 'friday']
#
# Tokens: ['guys', 'have', 'orgs', 'that', 'aim', 'serve', 'indigenous', 'people', 'heard', 'about', 'one', 'org', 'that', 'does', 'photo', 'ops', 'with', 'them', 'and', 'another', 'that', 'like', 'focus', 'group', 'discussions', 'and', 'intellectual', 'talks', 'ganun', 'ganun', 'pero', 'they', 'sound', 'corny', 'and', 'don', 'really', 'much', 'for', 'the', 'community', 'daw', 'idk', 'but', 'wanted', 'know', 'ifwe', 'had', 'more', 'serious', 'orgs', 'like', 'not', 'just', 'feel', 'good', 'and', 'smart', 'groups', 'something', 'more', 'impactful', 'ganun', 'hope', 'somebody', 'can', 'point', 'the', 'right', 'direction', 'sohphomore']
#
# Tokens: ['lemon', 'stop', 'coco']
#
# Tokens: ['fwcurrent', 'how', 'did', 'dlsu', 'become', 'the', 'number', 'university', 'the', 'while', 'are', 'getting', 'left', 'behind']
#
# Tokens: ['are', 'allowed', 'skate', 'campus']
#
# Tokens: ['whenever', 'someone', 'the', 'freedom', 'wall', 'starts', 'ranting', 'about', 'politics']
#
# Tokens: ['support', 'niyo', 'bandscreening', 'sat', 'thank', 'youuuuuuuuu']
#
# Tokens: ['putting', 'the', 'sose', 'theory', 'the', 'test', 'who', 'richer', 'the', 'average', 'soh', 'major', 'the', 'average', 'sose', 'major', 'the', 'sose', 'supremacist', 'would', 'contend', 'that', 'soh', 'majors', 'are', 'rich', 'and', 'could', 'afford', 'soh', 'majors', 'where', 'the', 'average', 'soh', 'job', 'pays', 'less', 'than', 'the', 'average', 'sose', 'job', 'emphasis', 'average', 'not', 'into', 'tails', 'mean', 'average', 'the', 'same', 'way', 'you', 'cannot', 'cross', 'river', 'just', 'because', 'average', 'feet', 'deep', 'the', 'other', 'hand', 'parents', 'lower', 'net', 'worth', 'will', 'more', 'inclined', 'sway', 'their', 'kids', 'towards', 'sose', 'not', 'necessarily', 'just', 'out', 'highschool', 'but', 'from', 'the', 'very', 'beginning', 'the', 'kids', 'lives', 'thus', 'the', 'kids', 'are', 'not', 'forced', 'into', 'sose', 'rather', 'the', 'kids', 'are', 'shown', 'the', 'wonders', 'math', 'and', 'science', 'from', 'their', 'birth', 'soh', 'majors', 'parents', 'are', 'likely', 'rich', 'soh', 'majors', 'themselves']
#
# Tokens: ['there', 'way', 'have', 'lan', 'party', 'with', 'the', 'mateo', 'down', 'computers']
#
# Tokens: ['safe']
#
# Tokens: ['here', 'the', 'real', 'tea', 'about', 'the', 'theatre', 'org', 'theatre', 'org', 'org', 'made', 'cliques', 'you', 'don', 'have', 'clique', 'your', 'own', 'you', 'gonna', 'live', 'miserable', 'lonely', 'life', 'made', 'mistake', 'don', 'worry', 'they', 'only', 'judge', 'every', 'move', 'you', 'make', 'and', 'reeeaaalllyyy', 'make', 'you', 'feel', 'unwelcome', 'every', 'time', 'you', 'walk', 'the', 'room', 'yes', 'these', 'are', 'bourgeois', 'kids', 'trying', 'make', 'broadway', 'expect', 'the', 'bitchy', 'mayabang', 'attitude', 'fake', 'ass', 'bitches', 'who', 'awww', 'love', 'you', 'you', 'doing', 'great', 'sweetie', 'omg', 'you', 'amazing', 'but', 'back', 'stabs', 'you', 'soon', 'they', 'see', 'you', 'not', 'listening', 'them', 'newbies', 'save', 'yourselves']
#
# Tokens: ['does', 'anybody', 'know', 'blonde', 'dude', 'wearing', 'eyeglasses', 'brings', 'his', 'big', 'guitar', 'sometimes', 'and', 'frequently', 'passes', 'ctc', 'som', 'asking', 'for', 'friend']
#
# Tokens: ['ever', 'since', 'that', 'guy', 'posted', 'about', 'students', 'being', 'regis', 'the', 'brother', 'sisterhood', 'that', 'there', 'were', 'once', 'between', 'just', 'suddenly', 'vanished', 'sad', 'though', 'that', 'ever', 'since', 'then', 'were', 'generalized', 'rich', 'apathetic', 'entitled', 'people', 'but', 'the', 'truth', 'there', 'are', 'still', 'some', 'people', 'here', 'who', 'fight', 'for', 'the', 'same', 'rights', 'and', 'advocacies', 'you', 'and', 'mean', 'come', 'you', 'not', 'perfect', 'either', 'lahat', 'din', 'kayo', 'may', 'mga', 'pagkakamali', 'may', 'mga', 'hipokrito', 'rin', 'inyo', 'the', 'point', 'this', 'post', 'really', 'not', 'generalize', 'sad', 'that', 'pitting', 'against', 'each', 'other', 'when', 'the', 'end', 'tayo', 'tayo', 'lang', 'din', 'naman', 'yung', 'mga', 'may', 'pinaglalaban', 'bansang', 'ito']
#
# Tokens: ['tangina', 'mga', 'nang', 'inbox', 'zone', 'mga', 'wala', 'kayong', 'puso', 'amputa']
#
# Tokens: ['units', 'lang', 'ang', 'thesis', 'the', 'same', 'your', 'theo', 'philo', 'histo', 'and', 'all', 'your', 'other', 'core', 'classes', 'yung', 'iba', 'more', 'may', 'may', 'the', 'same', 'weight', 'your', 'majors', 'maybe', 'even', 'less', 'treat', 'your', 'thesis', 'the', 'way', 'you', 'treat', 'all', 'your', 'other', 'classes', 'treat', 'all', 'your', 'other', 'classes', 'the', 'way', 'you', 'treat', 'your', 'thesis', 'don', 'exhaust', 'all', 'your', 'effort', 'into', 'one', 'subject', 'kailangan', 'niyo', 'lahat', 'para', 'grumaduate', 'hindi', 'lang', 'hindi', 'lang', 'hindi', 'lang']
#
# Tokens: ['possible', 'for', 'senior', 'like', 'freshie', 'she', 'cute', 'kasi', 'shy', 'and', 'unassuming', 'manner', 'and', 'weak', 'for', 'those', 'types']
#
# Tokens: ['believe', 'the', 'best', 'way', 'break', 'this', 'wall', 'climb', 'you', 'slowly', 'step', 'step', 'you', 'don', 'rush', 'and', 'say', 'immediately', 'they', 'gonna', 'like', 'you', 'have', 'build', 'relationship', 'with', 'anything', 'you', 'build', 'slowly', 'https', 'youtu', 'rys']
#
# Tokens: ['hello', 'admu', 'rly', 'need', 'help', 'like', 'this', 'girl', 'pero', 'idk', 'how', 'talk', 'and', 'make', 'landi', 'plus', 'shes', 'always', 'with', 'her', 'friends', 'kinda', 'scared', 'like', 'try', 'join', 'her', 'squad', 'and', 'btw', 'socially', 'awkward', 'and', 'think', 'she', 'din', 'pls', 'help', 'legit', 'need', 'tips']
#
# Tokens: ['ayt', 'finally', 'ready', 'rally']
#
# Tokens: ['ahs', 'admu', 'aegis', 'shoot', 'please']
#
# Tokens: ['ang', 'sungit', 'ate', 'som', 'photocopying', 'station']
#
# Tokens: ['wish', 'could', 'show', 'people', 'true', 'self', 'especially', 'her', 'unfortunately', 'always', 'the', 'person', 'who', 'can', 'even', 'create', 'sustainable', 'conversation', 'with', 'her', 'ugh', 'torpeeee', 'probs']
#
# Tokens: ['been', 'thinking', 'about', 'this', 'for', 'quite', 'some', 'time', 'now', 'and', 'pretty', 'sure', 'the', 'problem', 'don', 'know', 'how', 'tell', 'friends', 'and', 'family', 'think', 'friends', 'would', 'still', 'accept', 'but', 'not', 'sure', 'family', 'will', 'the', 'same', 'well', 'think', 'mom', 'would', 'understand', 'and', 'support', 'but', 'don', 'think', 'dad', 'would', 'scared', 'really', 'heavy', 'keeping', 'this', 'myself']
#
# Tokens: ['asan', 'yung', 'batang', 'may', 'dahon', 'ulo']
#
# Tokens: ['subscribe', 'pewdiepie', 'doing', 'part', 'now', 'yours']
#
# Tokens: ['she', 'says', 'also', 'with', 'tagalog', 'accent', 'the', 'also', 'agreement', 'instead', 'too', 'you', 'know', 'she', 'from', 'som']
#
# Tokens: ['hello', 'everyone', 'please', 'help', 'find', 'fili', 'notebook', 'its', 'muji', 'but', 'doesnt', 'have', 'name', 'and', 'kasama', 'nya', 'also', 'muji', 'pencil', 'case', 'with', 'pens', 'inside', 'and', 'ruler', 'pls', 'need', 'for', 'finals', 'last', 'seen', 'kostka', 'last', 'tuesday', 'nov']
#
# Tokens: ['need', 'help', 'with', 'refunding', 'japanese', 'lessons', 'enrollment', 'yuno', 'xanland', 'place', 'front', 'admu', 'deposited', 'for', 'the', 'first', 'half', 'lessons', 'already', 'but', 'they', 'won', 'let', 'refund', 'anymore', 'need', 'transfer', 'someone', 'else', 'need', 'find', 'someone', 'who', 'about', 'enroll', 'and', 'just', 'let', 'them', 'take', 'slot', 'instead', 'exchange', 'for', 'helping', 'out', 'you', 'can', 'pay', 'less', 'just', 'comment', 'below', 'and', 'send', 'you', 'message']
#
# Tokens: ['hey', 'double', 'standards', 'sexism', 'and', 'prejudice', 'applies', 'both', 'men', 'and', 'women', 'how', 'about', 'instead', 'believing', 'your', 'victim', 'grow', 'the', 'fuck', 'and', 'watch', 'ben', 'shapiro', 'video', 'you', 'fockin', 'snowflake']
#
# Tokens: ['mean', 'the', 'react', 'sticker', 'system', 'cool', 'and', 'all', 'but', 'its', 'still', 'confusing', 'especially', 'certain', 'news', 'posts', 'are', 'the', 'angry', 'reacts', 'because', 'being', 'angry', 'the', 'news', 'the', 'website', 'for', 'attacking', 'certain', 'someone']
#
# Tokens: ['when', 'you', 'try', 'your', 'best', 'but', 'you', 'don', 'succeed', 'this', 'line', 'from', 'coldplay', 'fix', 'you', 'keeps', 'replaying', 'head', 'this', 'how', 'feel', 'with', 'philo', 'really', 'try', 'best', 'explain', 'the', 'topics', 'the', 'exams', 'but', 'still', 'get', 'low', 'grade', 'how', 'get', 'good', 'grade', 'philo', 'please', 'help', 'huhuhu']
#
# Tokens: ['unpopular', 'opinion', 'the', 'chinese', 'were', 'take', 'our', 'islands', 'the', 'west', 'philippine', 'sea', 'would', 'gladly', 'let', 'them', 'they', 'had', 'proven', 'record', 'being', 'good', 'environmental', 'stewards', 'the', 'thing', 'they', 'don', 'they', 'take', 'tiger', 'bone', 'powder', 'and', 'rhino', 'horn', 'medicine', 'eat', 'sharksfin', 'soup', 'and', 'reclaim', 'land', 'building', 'top', 'coral', 'reefs', 'they', 'also', 'smoke', 'like', 'chimneys', 'and', 'throw', 'the', 'butts', 'the', 'sea', 'and', 'the', 'street', 'not', 'all', 'chinese', 'are', 'like', 'this', 'but', 'everywhere', 'see', 'those', 'who', 'are', 'and', 'these', 'are', 'the', 'people', 'are', 'entrusting', 'with', 'our', 'coral', 'reefs', 'and', 'forests', 'were', 'the', 'president', 'would', 'bargain', 'our', 'rightful', 'land', 'away', 'some', 'foreign', 'government', 'that', 'actually', 'gave', 'damn', 'for', 'the', 'environment']
#
# Tokens: ['nietzsche', 'dead', 'god']
#
# Tokens: ['tag', 'your', 'cute', 'math', 'major', 'friends']
#
# Tokens: ['hii', 'may', 'aattend', 'rib', 'here', 'hehe', 'worth', 'and', 'full', 'house']
#
# Tokens: ['idk', 'how', 'people', 'still', 'chew', 'with', 'their', 'mouths', 'fricking', 'open', 'grow']
#
# Tokens: ['jef', 'the', 'eagle', 'admin', 'senior', 'what', 'are', 'your', 'plans', 'for', 'the', 'page', 'after', 'you', 'graduate']
#
# Tokens: ['can', 'anyone', 'who', 'taking', 'baseball', 'softball', 'for', 'please', 'tell', 'what', 'like', 'you', 'play', 'games', 'and', 'how', 'they', 'teach', 'you', 'the', 'sport', 'very', 'interested', 'since', 'considering', 'for', 'next', 'semester']
#
# Tokens: ['with', 'great', 'sadness', 'that', 'acknowledge', 'the', 'phasing', 'out', 'the', 'great', 'bon', 'chon', 'gangnam', 'bao', 'these', 'monsters', 'really', 'think', 'they', 'can', 'replace', 'you', 'with', 'that', 'nasty', 'double', 'loaded', 'sandwich', 'don', 'even', 'see', 'chops', 'rice', 'box', 'the', 'menu', 'anymore', 'another', 'bad', 'omen']
#
# Tokens: ['you', 'know', 'what', 'annoying', 'facing', 'the', 'fact', 'that', 'you', 'are', 'jealous', 'but', 'also', 'knowing', 'that', 'you', 'not', 'the', 'position', 'because', 'the', 'both', 'you', 'are', 'friends']
#
# Tokens: ['why', 'can', 'grow', 'facial', 'hair', 'ampota']
#
# Tokens: ['watch', 'out', 'ateneans', 'here', 'tell', 'you', 'about', 'scammy', 'atenean', 'graduate', 'who', 'runs', 'scam', 'markets', 'youth', 'development', 'program', 'barangays', 'supposedly', 'incubates', 'projects', 'the', 'barangay', 'that', 'can', 'improve', 'the', 'catch', 'asks', 'for', 'insane', 'amount', 'money', 'hundreds', 'thousands', 'from', 'the', 'lgu', 'run', 'his', 'program', 'but', 'how', 'many', 'those', 'projects', 'actually', 'come', 'life', 'hmm', 'and', 'where', 'does', 'all', 'that', 'money', 'hmm', 'also', 'sends', 'people', 'the', 'and', 'asks', 'for', 'crazy', 'amount', 'money', 'too', 'heard', 'the', 'participants', 'his', 'training', 'program', 'for', 'this', 'thing', 'always', 'have', 'ton', 'complaints', 'because', 'not', 'run', 'well', 'this', 'what', 'ateneo', 'taught', 'this', 'development', 'scammy', 'just', 'using', 'people', 'and', 'barangays', 'for', 'money', 'and', 'scammy', 'also', 'likes', 'take', 'credit', 'for', 'his', 'team', 'work', 'without', 'doing', 'any', 'the', 'actual', 'work', 'just', 'likes', 'the', 'photo', 'ops', 'high', 'level', 'places', 'looks', 'cool', 'think', 'three', 'full', 'core', 'teams', 'have', 'quit', 'under', 'him', 'because', 'his', 'lack', 'professionalism', 'come', 'scammy', 'ateneans', 'you', 'have', 'been', 'warned', 'don', 'fall', 'for', 'pretty', 'marketing', 'with', 'substance']
#
# Tokens: ['been', 'seeing', 'this', 'guy', 'starbucks', 'katip', 'who', 'think', 'cute', 'wears', 'mea', 'lanyard', 'and', 'wears', 'glasses', 'heard', 'his', 'friends', 'call', 'him', 'him', 'julius', 'juju', 'idk', 'wasn', 'able', 'hear', 'clearly', 'but', 'yea', 'anyone', 'can', 'tag', 'him', 'would', 'appreciate', 'rapsa', 'niya', 'hahahha']
#
# Tokens: ['ang', 'landi']
#
# Tokens: ['great', 'day', 'you', 'all', 'except', 'the', 'little', 'shit', 'who', 'stole', 'umbrella']
#
# Tokens: ['wholesome', 'shit', 'only', 'doods']
#
# Tokens: ['people', 'are', 'losing', 'their', 'shit', 'audio', 'just', 'binaural', 'audio', 'spinning', 'around', 'ffs', 'and', 'annoying']
#
# Tokens: ['really', 'like', 'this', 'mgt', 'girl', 'from', 'english', 'class', 'but', 'idk', 'she', 'taken', 'interested', 'wish', 'wasn', 'shy', 'dammit', 'send', 'help', 'how', 'make', 'landi', 'sose', 'freshie']
#
# Tokens: ['when', 'you', 'feel', 'like', 'you', 'special', 'him', 'but', 'guess', 'what', 'just', 'your', 'feelings', 'fleeting', 'does', 'matter', 'they', 'will', 'like', 'you', 'back', 'never', 'does', 'because', 'that', 'when', 'you', 'realize', 'there', 'point', 'telling', 'them', 'you', 'love', 'them', 'when', 'they', 'can', 'love', 'you', 'back']
#
# Tokens: ['can', 'have', 'prom', 'just', 'wanna', 'slow', 'dance', 'with', 'the', 'girl', 'like']
#
# Tokens: ['okay', 'here', 'update', 'from', 'post', 'submitted', 'back', 'september', 'for', 'reference', 'palapit', 'ang', 'finals', 'and', 'for', 'some', 'reason', 'still', 'fuckin', 'attracted', 'classmate', 'that', 'found', 'super', 'duper', 'cute', 'like', 'wth', 'patapos', 'yung', 'sem', 'tapos', 'wala', 'naman', 'nangyayari', 'bobo', 'lang', 'ako', 'now', 'just', 'kinda', 'hate', 'him', 'because', 'wala', 'tangina', 'gusto', 'rin', 'siya', 'huhu', 'gave', 'trying', 'halaman', 'altogether', 'but', 'also', 'kinda', 'gave', 'him', 'some', 'point', 'kasi', 'sobrang', 'wala', 'kaming', 'common', 'friend', 'circles', 'common', 'activities', 'except', 'that', 'one', 'class', 'have', 'together', 'and', 'was', 'super', 'obvious', 'with', 'him', 'and', 'got', 'the', 'feel', 'sinusungitan', 'niya', 'ako', 'ergo', 'siya', 'interested', 'tapos', 'out', 'nowhere', 'kinausap', 'niya', 'ako', 'after', 'class', 'know', 'that', 'nbd', 'pero', 'isipin', 'isipin', 'yung', 'sobrang', 'crush', 'crush', 'isang', 'tao', 'tapos', 'sinungitan', 'nila', 'tapos', 'kumbinsado', 'ayaw', 'ayaw', 'nila', 'sayo', 'tapos', 'biglang', 'kakausapin', 'nila', 'naku', 'kuya', 'mahirap', 'yan', 'maropoque', 'kaya', 'ayan', 'naloka', 'ako', 'all', 'over', 'again', 'tumingin', 'ulit', 'ako', 'horoscope', 'para', 'lang', 'may', 'reference', 'ako', 'some', 'sort', 'kung', 'type', 'sign', 'niya', 'yung', 'girl', 'yung', 'magmamake', 'first', 'move', 'honestly', 'sobrang', 'bobo', 'lang', 'like', 'really', 'gonna', 'base', 'actions', 'his', 'natal', 'chart', 'tbh', 'probably', 'but', 'sobrang', 'apparently', 'his', 'sign', 'will', 'try', 'anything', 'once', 'was', 'kinda', 'banking', 'that', 'but', 'ayun', 'recently', 'decided', 'okay', 'fine', 'ask', 'him', 'out', 'fuck', 'gonna', 'what', 'the', 'worst', 'that', 'could', 'happen', 'been', 'rejected', 'several', 'times', 'before', 'can', 'handle', 'and', 'started', 'telling', 'people', 'parang', 'okay', 'gonna', 'kahit', 'sobrang', 'mukhang', 'cannot', 'susubukan', 'kasi', 'will', 'never', 'know', 'for', 'sure', 'after', 'asking', 'for', 'some', 'advice', 'figured', 'sige', 'can', 'build', 'talking', 'him', 'for', 'few', 'times', 'muna', 'after', 'class', 'before', 'really', 'asking', 'him', 'out', 'kahit', 'one', 'meeting', 'lang', 'ayun', 'hinahype', 'sarili', 'kakausapin', 'siya', 'after', 'class', 'ito', 'ito', 'tapos', 'alam', 'yung', 'movies', 'yung', 'hahabulin', 'main', 'character', 'yung', 'gusto', 'nila', 'tapos', 'biglang', 'pag', 'nag', 'pan', 'yung', 'camera', 'may', 'kasamang', 'iba', 'agoyyyyyy', 'there', 'was', 'girl', 'waiting', 'for', 'him', 'and', 'they', 'walked', 'together', 'and', 'like', 'ang', 'sakit', 'mga', 'pare', 'bro', 'feel', 'naman', 'tropa', 'lang', 'sila', 'pero', 'alam', 'yung', 'sobrang', 'naramdaman', 'lang', 'lalo', 'magka', 'ibang', 'mundo', 'kami', 'and', 'sobrang', 'longshot', 'talaga', 'and', 'parang', 'has', 'enough', 'girls', 'around', 'him', 'and', 'hindi', 'kami', 'same', 'crowd', 'rin', 'ako', 'tugma', 'personality', 'mga', 'girls', 'that', 'usually', 'hangs', 'around', 'but', 'also', 'for', 'some', 'reason', 'parang', 'this', 'the', 'third', 'time', 'since', 'freshman', 'year', 'seen', 'this', 'same', 'girl', 'with', 'guy', 'like', 'and', 'parang', 'ate', 'girl', 'tulong', 'how', 'tapos', 'ata', 'siya', 'orsem', 'crush', 'wow', 'extra', 'oof', 'oof', 'lang', 'talaga']
#
# Tokens: ['spent', 'the', 'past', 'months', 'feuding', 'with', 'two', 'friends', 'met', 'both', 'separately', 'different', 'stages', 'life', 'each', 'them', 'was', 'there', 'for', 'growing', 'hope', 'was', 'able', 'help', 'them', 'some', 'way', 'too', 'all', 'knew', 'each', 'other', 'but', 'felt', 'the', 'two', 'them', 'were', 'the', 'same', 'side', 'against', 'after', 'shit', 'hit', 'the', 'fan', 'two', 'them', 'were', 'best', 'friends', 'from', 'way', 'back', 'even', 'before', 'became', 'friends', 'with', 'either', 'one', 'them', 'only', 'came', 'along', 'much', 'later', 'and', 'even', 'became', 'friends', 'with', 'them', 'individually', 'and', 'three', 'have', 'only', 'ever', 'hung', 'out', 'all', 'together', 'twice', 'below', 'whenever', 'imagine', 'losing', 'you', 'both', 'with', 'you', 'two', 'avoiding', 'were', 'some', 'fucking', 'nazi', 'rapist', 'pedophile', 'scum', 'who', 'does', 'not', 'deserve', 'live', 'really', 'wish', 'can', 'all', 'friends', 'want', 'you', 'know', 'love', 'you', 'both', 'painful', 'thinking', 'you', 'both', 'might', 'still', 'hate', 'guts']
#
# Tokens: ['what', 'the', 'system', 'allows', 'its', 'students', 'feel', 'depressed', 'suicidal', 'constant', 'state', 'poor', 'mental', 'health', 'there', 'certain', 'degree', 'challenge', 'that', 'students', 'need', 'but', 'does', 'have', 'reach', 'the', 'point', 'sacrificing', 'one', 'mental', 'health', 'for', 'grades', 'and', 'staying', 'college', 'this', 'semester', 'has', 'been', 'way', 'too', 'hard', 'for', 'many', 'people', 'wish', 'could', 'end', 'please', 'take', 'care', 'yourselves']
#
# Tokens: ['friendship', 'relationship', 'paulit', 'ulit', 'nang', 'sinasabi', 'sarili', 'pero', 'gago', 'gusto', 'parin', 'kita', 'ganto']
#
# Tokens: ['can', 'someone', 'please', 'explain', 'wtf', 'going', 'with', 'the', 'frats', 'ang', 'supot', 'ateneo', 'walang', 'frat']
#
# Tokens: ['the', 'other', 'day', 'friend', 'asked', 'who', 'was', 'the', 'best', 'person', 'met', 'far', 'during', 'first', 'year', 'college', 'and', 'don', 'know', 'why', 'but', 'just', 'blurted', 'out', 'kuya', 'resty', 'from', 'faura', 'that', 'guard', 'heckin', 'solid', 'dude', 'you', 'have', 'classes', 'there', 'you', 'just', 'passing', 'faura', 'make', 'sure', 'you', 'greet', 'him', 'cause', 'surely', 'greet', 'you', 'with', 'the', 'usual', 'sir', 'just', 'appreciation', 'post', 'for', 'all', 'the', 'guards', 'arounds', 'campus', 'because', 'they', 'really', 'care', 'about', 'you', 'gives', 'solid', 'advice', 'and', 'has', 'this', 'super', 'duper', 'kuwentuhan', 'buddy', 'vibe', 'wah', 'pls', 'protect', 'this', 'man']
#
# Tokens: ['hello', 'engejowa', 'are', 'you', 'still', 'looking', 'for', 'jowa']
#
# Tokens: ['everybody', 'has', 'story', 'behind', 'that', 'cigarette', 'that', 'they', 'smoke', 'some', 'people', 'smoke', 'because', 'they', 'think', 'its', 'cool', 'some', 'people', 'smoke', 'because', 'its', 'part', 'their', 'routine', 'but', 'the', 'reason', 'smoke', 'because', 'girl', 'girl', 'whom', 'love', 'much', 'hurts', 'the', 'urge', 'see', 'and', 'talk', 'her', 'always', 'there', 'the', 'smile', 'from', 'her', 'angelic', 'face', 'never', 'fails', 'make', 'feel', 'loved', 'but', 'course', 'where', 'there', 'light', 'there', 'darkness', 'hurts', 'when', 'you', 'feel', 'comfort', 'from', 'anyone', 'when', 'the', 'love', 'your', 'life', 'longer', 'yours', 'you', 'feel', 'like', 'nothing', 'matters', 'she', 'doesnt', 'even', 'care', 'about', 'what', 'you', 'anymore', 'she', 'hurt', 'you', 'like', 'you', 'were', 'one', 'her', 'also', 'imagine', 'getting', 'betrayed', 'your', 'friends', 'when', 'you', 'treated', 'them', 'like', 'family', 'yeah', 'that', 'happened', 'too', 'would', 'even', 'die', 'for', 'them', 'even', 'help', 'them', 'hide', 'dead', 'body', 'they', 'needed', 'everything', 'hurts', 'the', 'point', 'you', 'numb', 'and', 'you', 'don', 'even', 'know', 'yourself', 'anymore', 'sometimes', 'you', 'just', 'dont', 'know', 'eho', 'trust', 'and', 'lean', 'that', 'where', 'cigarette', 'comes', 'comforts', 'whenever', 'feel', 'alone', 'and', 'unwanted', 'just', 'makes', 'you', 'forget', 'about', 'the', 'problems', 'that', 'you', 'have', 'comes', 'with', 'the', 'smoke', 'that', 'you', 'release', 'from', 'between', 'your', 'lips', 'guys', 'whenever', 'you', 'see', 'smoker', 'just', 'ask', 'him', 'her', 'about', 'his', 'her', 'life', 'dont', 'judge', 'him', 'her', 'right', 'away', 'because', 'you', 'never', 'know', 'the', 'story', 'behind', 'that', 'burnt', 'cigarette']
#
# Tokens: ['maraming', 'cuties', 'flc', 'class']
#
# Tokens: ['admufreedomwall', 'bud', 'the', 'same', 'boat', 'best', 'friend', 'and', 'are', 'partners', 'girl', 'who', 'very', 'lucky', 'have', 'unfortunately', 'not', 'the', 'official', 'partner', 'since', 'bestie', 'clingy', 'and', 'they', 'the', 'couple', 'that', 'our', 'friends', 'see', 'often', 'really', 'can', 'helped', 'our', 'case', 'and', 'frustrates', 'end', 'but', 'kinda', 'timing', 'before', 'come', 'out', 'friends', 'even', 'they', 'won', 'understand', 'least', 'tried', 'right', 'both', 'love', 'her', 'and', 'want', 'able', 'say', 'without', 'being', 'afraid', 'any', 'tips', 'from', 'polyam', 'fam', 'welcome']
#
# Tokens: ['rip', 'dlsu']
#
# Tokens: ['love', 'with', 'roommate', 'but', 'straight', 'and', 'that', 'just', 'sad']
#
# Tokens: ['pupunta', 'ako', 'buybust', 'para', 'manood', 'para', 'makita', 'crush', 'lfc', 'hehe']
#
# Tokens: ['waitt', 'there', 'minor', 'humanitarian', 'action', 'ateneo']
#
# Tokens: ['the', 'guy', 'kumuha', 'bath', 'essentials', 'tangina', 'sana', 'maging', 'mabango', 'and', 'maging', 'soft', 'hair', 'pakyu']
#
# Tokens: ['seriously', 'hoping', 'polyamory', 'becomes', 'valid', 'and', 'not', 'seen', 'weird', 'cheating', 'being', 'not', 'decisive', 'because', 'much', 'partners', 'want', 'come', 'out', 'they', 'scared', 'what', 'their', 'friends', 'will', 'say', 'all', 'from', 'trad', 'families', 'not', 'option', 'come', 'out', 'them', 'hard', 'too', 'since', 'also', 'know', 'they', 'don', 'wanna', 'hide', 'our', 'relationship', 'either']
#
# ...
#
# Tokens: ['ang', 'ganda', 'pag', 'asa', 'pero', 'kapag', 'hndi', 'siya', 'paasa', 'lng', 'sarili', 'malulungkot', 'lamang']
#
# Tokens: ['want', 'more', 'padking', 'parking', 'parking', 'parking', 'parking', 'parking', 'parking', 'parking', 'grr']
#
# Tokens: ['why', 'was', 'aegis', 'announced', 'late', 'soon', 'why', 'are', 'the', 'photoshoots', 'for', 'sose', 'students', 'during', 'nmat', 'season', 'not', 'all', 'sose', 'majors', 'will', 'take', 'the', 'nmat', 'but', 'lets', 'say', 'good', 'will', 'not', 'batak', 'yet', 'hold', 'world']
#
# Tokens: ['admufreedomwall', 'saw', 'the', 'comments', 'that', 'marikina', 'side', 'sunrise', 'while', 'katipunan', 'side', 'sunset', 'apologies', 'for', 'that', 'mistake', 'though', 'you', 'should', 'still', 'witness', 'dawn', 'dusk', 'that', 'area', 'must', 'been', 'high', 'remember', 'the', 'opposite', 'damn']
#
# Tokens: ['gremlin', 'shirt', 'batak', 'guy']
#
# Tokens: ['life', 'with', 'mak', 'truly', 'skinny', 'legend', 'who', 'also', 'advocate', 'the', 'lgbtq', 'community', 'ugh', 'her', 'mind', 'too', 'powerful', 'for', 'this', 'world']
#
# Tokens: ['there', 'used', 'this', 'cool', 'and', 'cute', 'guy', 'who', 'always', 'stayed', 'the', 'ama', 'area', 'jsec', 'last', 'year', 'hes', 'tall', 'chinky', 'kinda', 'long', 'hair', 'ish', 'but', 'then', 'like', 'disappeared', 'graduated', 'hahaha', 'wonder', 'where']
#
# Tokens: ['groupmates', 'where', 'are', 'you', 'jeff', 'jeff', 'just', 'arrived', 'chat', 'while', 'deadline', 'near', 'have', 'long', 'test', 'starting', 'the', 'deadline', 'fuck', 'everyone', 'else']
#
# Tokens: ['bad', 'that', 'have', 'crushes', 'block']
#
# Tokens: ['isn', 'weird', 'people', 'don', 'share', 'tables', 'jsec', 'but', 'common', 'practice', 'gonzaga']
#
# Tokens: ['big', 'fish']
#
# Tokens: ['kinda', 'sickening', 'how', 'people', 'think', 'that', 'genetic', 'monstrosities', 'like', 'bulldogs', 'pugs', 'and', 'bull', 'terriers', 'are', 'cute', 'their', 'not', 'they', 'have', 'disgusting', 'genetic', 'deformities', 'that', 'damage', 'their', 'bodies', 'have', 'you', 'guys', 'even', 'heard', 'how', 'pugs', 'breath', 'they', 'make', 'this', 'grotesque', 'snorting', 'sound', 'constantly', 'and', 'are', 'actually', 'struggling', 'you', 'sick', 'fucks', 'they', 'should', 'just', 'allowed', 'become', 'extinct', 'with', 'time']
#
# Tokens: ['what', 'the', 'point', 'living', 'when', 'you', 'feel', 'that', 'you', 'don', 'matter', 'anyone', 'all']
#
# Tokens: ['where', 'the', 'best', 'study', 'place', 'ateneo']
#
# Tokens: ['pota', 'gwapo', 'talaga', 'franco', 'dytianquin']
#
# Tokens: ['tangina', 'wala', 'akong', 'gets', 'math', 'tulungan', 'naman', 'tayo', 'seatwork', 'bukas', 'sige']
#
# Tokens: ['scrolling', 'down', 'this', 'page', 'cus', 'avoiding', 'paper']
#
# Tokens: ['bawal', 'magka', 'block', 'crush']
#
# Tokens: ['remember', 'that', 'someone', 'probably', 'loves', 'you', 'much', 'you', 'love', 'that', 'crush', 'yours']
#
# Tokens: ['tfw', 'you', 'have', 'pos', 'under', 'aguirre', 'and', 'you', 'haven', 'read', 'any', 'the', 'readings', 'yet']
#
# Tokens: ['girls', 'who', 'drive', 'small', 'cars', 'have', 'big', 'dick', 'energy']
#
# Tokens: ['atenean', 'sjws', 'are', 'easily', 'baited', 'the', 'point', 'where', 'their', 'reactions', 'are', 'hilarious']
#
# Tokens: ['why', 'people', 'cheat', 'because', 'the', 'temptation', 'really', 'natural', 'because', 'insecure', 'the', 'others', 'were', 'beautiful', 'stunning', 'even', 'used', 'confident', 'about', 'how', 'look', 'and', 'act', 'now', 'swallow', 'pride', 'and', 'eventually', 'lost', 'the', 'confidence', 'used', 'have', 'saved', 'for', 'skincare', 'products', 'gym', 'fees', 'diet', 'food', 'all', 'just', 'please', 'him', 'but', 'the', 'end', 'was', 'taken', 'for', 'granted', 'everyone', 'tells', 'nice', 'and', 'friendly', 'and', 'loving', 'but', 'why', 'honest', 'tried', 'cheat', 'too', 'just', 'feel', 'what', 'like', 'wanted', 'know', 'why', 'did', 'over', 'and', 'over', 'again', 'was', 'miserable', 'emailing', 'those', 'who', 'are', 'looking', 'for', 'fubus', 'fwbs', 'momol', 'buddies', 'and', 'the', 'like', 'felt', 'guilty', 'everytime', 'typed', 'message', 'and', 'eventually', 'don', 'reply', 'when', 'they', 'send', 'their', 'reply', 'still', 'love', 'him', 'and', 'stupid', 'for', 'that', 'don', 'have', 'the', 'heart', 'break', 'with', 'him', 'and', 'just', 'end', 'crying', 'myself', 'because', 'know', 'that', 'the', 'love', 'you', 'exchanged', 'were', 'half', 'meant', 'because', 'only', 'meant', 'and', 'can', 'anyone', 'answer', 'question', 'above', 'please', 'love', 'hear', 'others', 'opinions', 'about', 'this', 'devastated', 'and', 'confused', 'right', 'now', 'and', 'would', 'mean', 'lot', 'thank', 'you']
#
# Tokens: ['every', 'time', 'finish', 'paper', 'other', 'major', 'requirement', 'say', 'myself', 'research', 'complete', 'the', 'warcraft', 'undead', 'advisor']
#
# Tokens: ['this', 'wagon', 'while', 'still', 'hot', 'readying', 'myself', 'for', 'the', 'inferno']
#
# Tokens: ['ampp', 'miss', 'causeway', 'bae', 'talaga', 'there', 'way', 'can', 'get', 'the', 'owners', 'join', 'bazaars', 'campus', 'open', 'stall', 'katip']
#
# Tokens: ['anyone', 'play', 'smash', 'admu', 'post', 'your', 'main', 'and', 'your', 'switch', 'friend', 'code']
#
# Tokens: ['anyone', 'was', 'polyamorous', 'relationship', 'need', 'advice', 'how', 'make', 'work']
#
# Tokens: ['find', 'annoying', 'how', 'some', 'students', 'automatically', 'assume', 'that', 'everyone', 'first', 'choice', 'school', 'and', 'everyone', 'who', 'not', 'failed', 'the', 'upcat', 'excuse', 'passed', 'both', 'the', 'acet', 'and', 'upcat', 'and', 'was', 'even', 'among', 'the', 'top', 'upcat', 'passers', 'but', 'chose', 'the', 'ateneo', 'because', 'believed', 'was', 'the', 'best', 'school', 'for', 'not', 'just', 'about', 'what', 'foreigners', 'think', 'the', 'ranking', 'schools', 'the', 'philippines', 'also', 'about', 'picking', 'the', 'school', 'that', 'you', 'think', 'the', 'best', 'fit', 'for', 'you', 'and', 'for', 'that', 'was', 'the', 'ateneo']
#
# Tokens: ['the', 'only', 'one', 'who', 'gets', 'grossed', 'out', 'about', 'how', 'oily', 'the', 'exit', 'door', 'rizal', 'lib', 'gets']
#
# Tokens: ['tengene', 'niyong', 'marunong', 'mag', 'spacing', 'parallel', 'parking', 'north', 'kayang', 'kaya', 'yung', 'malaking', 'kotse', 'pag', 'maayos', 'lang', 'spacing', 'niyo', 'ihhhhh']
#
# Tokens: ['senior', 'now', 'and', 'still', 'paranoid', 'that', 'batch', 'mates', 'think', 'stupid', 'have', 'relatively', 'high', 'energy', 'and', 'when', 'really', 'good', 'mood', 'tend', 'talk', 'like', 'dumb', 'blond', 'heck', 'even', 'terrified', 'that', 'own', 'candidate', 'laude', 'friends', 'think', 'stupid']
#
# Tokens: []
#
# Tokens: ['caesar', 'deserved', 'die', 'sauce', 'florkofcows']
#
# Tokens: ['really', 'atenean', 'paper', 'there', 'pointledd', 'anecdote']
#
# Tokens: ['why', 'are', 'physics', 'majors', 'the', 'cutest', 'ateneo', 'there', 'this', 'one', 'guy', 'tanghalang', 'ateneo', 'and', 'there', 'this', 'one', 'guy', 'gabay', 'and', 'fellow', 'freshman', 'from', 'sose', 'whose', 'insufficient', 'details', 'from', 'his', 'facebook', 'profile', 'limits', 'any', 'investigation', 'skills', 'further', 'and', 'find', 'out', 'too', 'from', 'the', 'physics', 'department', 'and', 'when', 'say', 'cute', 'kasama', 'rin', 'height', 'hahahaha', 'the', 'worst', 'part', 'actually', 'detest', 'physics', 'mean', 'have', 'history', 'getting', 'the', 'merits', 'and', 'distinctions', 'physics', 'previous', 'schools', 'but', 'just', 'can', 'get', 'myself', 'least', 'even', 'like', 'the', 'subject', 'something', 'about', 'parabola', 'free', 'fall', 'quantum', 'mechanics', 'and', 'mathematical', 'equations', 'guess', 'hahaha', 'and', 'looks', 'like', 'now', 'that', 'need', 'come', 'terms', 'with', 'something', 'hate', 'have', 'least', 'common', 'ground', 'talk', 'about', 'when', 'get', 'the', 'chance', 'with', 'the', 'people', 'that', 'deem', 'admirable']
#
# Tokens: ['all', 'the', 'sadboi', 'sadgorl', 'posts', 'about', 'confessing', 'the', 'ones', 'they', 'admire', 'and', 'have', 'failed', 'least', 'you', 'tried', 'and', 'maybe', 'she', 'really', 'isn', 'the', 'one', 'for', 'you', 'but', 'glad', 'that', 'you', 'were', 'able', 'muster', 'the', 'courage', 'confess', 'ask', 'them', 'out', 'believe', 'better', 'let', 'loose', 'and', 'let', 'instead', 'keeping', 'and', 'eventually', 'never', 'opening', 'about', 'life', 'goes', 'and', 'keep', 'loving']
#
# Tokens: ['ang', 'solid', 'lions', 'orgs']
#
# Tokens: ['anong', 'gagawin', 'pag', 'sinisiraan', 'isang', 'lalaki', 'dahil', 'may', 'gusto', 'siya', 'sayo']
#
# Tokens: ['the', 'god', 'king', 'destroyer', 'worlds', 'rammus']
#
# Tokens: ['would', 'highly', 'recommend', 'walking', 'around', 'campus', 'mid', 'afternoon', 'ish', 'while', 'listening', 'the', 'howl', 'moving', 'castle', 'main', 'theme', 'any', 'studio', 'ghibli', 'soundtrack', 'for', 'that', 'matter', 'did', 'that', 'few', 'days', 'ago', 'way', 'bel', 'from', 'covered', 'courts', 'and', 'with', 'that', 'being', 'the', 'accompaniment', 'the', 'breeze', 'and', 'the', 'not', 'too', 'harsh', 'sunlight', 'made', 'forget', 'had', 'problems', 'and', 'deadlines', 'for', 'least', 'minutes', 'ang', 'ganda', 'feeling', 'thanks', 'joe', 'hisashi']
#
# Tokens: ['dami', 'niyong', 'oras', 'mag', 'facebook', 'pahingi', 'naman']
#
# Tokens: ['admu', 'study', 'buddy', 'hellooo', 'again', 'the', 'original', 'post', 'admufreedomwall', 'had', 'more', 'than', 'enough', 'favorable', 'responses', 'and', 'even', 'some', 'from', 'despite', 'the', 'name', 'admu', 'study', 'buddy', 'will', 'also', 'open', 'non', 'ateneans', 'who', 'are', 'studying', 'katip', 'ensure', 'that', 'only', 'students', 'from', 'katip', 'universities', 'are', 'the', 'sheet', 'require', 'submissions', 'use', 'their', 'school', 'email', 'addresses', 'how', 'does', 'this', 'work', 'first', 'step', 'fill', 'out', 'this', 'form', 'https', 'goo', 'forms', 'uueikcb', 'hswkaf', 'second', 'step', 'check', 'out', 'the', 'gsheet', 'and', 'look', 'for', 'someone', 'study', 'with', 'https', 'goo', 'nqukyq', 'third', 'step', 'email', 'the', 'person', 'you', 'wish', 'study', 'with', 'polite', 'fourth', 'step', 'wait', 'for', 'the', 'person', 'reply', 'for', 'someone', 'email', 'you', 'these', 'are', 'only', 'for', 'september', 'october', 'another', 'form', 'and', 'sheet', 'will', 'uploaded', 'there', 'still', 'demand', 'for', 'something', 'like', 'this', 'would', 'greatly', 'appreciate', 'you', 'could', 'share', 'this', 'with', 'your', 'friends', 'and', 'help', 'spread', 'the', 'word', 'you', 'know', 'what', 'they', 'say', 'the', 'more', 'the', 'merrier']
#
# Tokens: ['show', 'love', 'your', 'homies']
#
# Tokens: ['try', 'resist', 'kim', 'jisoo', 'dare', 'you']
#
# Tokens: ['who', 'the', 'super', 'cool', 'cop', 'always', 'gets', 'the', 'bad', 'guy', 'donut', 'boy', 'that', 'yeah', 'bring', 'delicious', 'assortment', 'sweet', 'delight', 'donut', 'boy', 'got', 'creamy', 'filling']
#
# Tokens: ['want', 'build', 'parking', 'building', 'ateneo']
#
# Tokens: ['like', 'when', 'boyfriend', 'asks', 'stuff', 'for', 'him', 'can', 'tease', 'back', 'about', 'his', 'love', 'warcraft', 'saying', 'yes', 'milord', 'jobs', 'done', 'what']
#
# Tokens: ['why', 'would', 'one', 'despair', 'they', 'are', 'machiavellian']
#
# Tokens: ['tag', 'cute', 'single', 'means']
#
# Tokens: ['want', 'stepped']
#
# Tokens: ['please', 'give', 'manga', 'webcomic', 'suggestions', 'plz', 'uwu']
#
# Tokens: ['oof']
#
# Tokens: ['eagle', 'even', 'the', 'heart', 'regis', 'iskos', 'can', 'still', 'feel', 'fear', 'spear', 'falls', 'from', 'the', 'sky', 'into', 'the', 'regis', 'building', 'isko', 'old', 'enemy', 'you', 'cannot', 'hide', 'from', 'matter', 'what', 'form', 'you', 'choose', 'wear', 'let', 'your', 'true', 'self', 'revealed', 'elitista', 'elitista', 'our', 'long', 'war', 'ends', 'day', 'isko', 'stabs', 'isko', 'isko', 'elitista', 'take', 'one', 'last', 'look', 'your', 'shining', 'regis', 'isko', 'for', 'soon', 'nothing', 'shall', 'remain', 'but', 'your', 'area', 'tosses', 'isko', 'aside', 'and', 'walks', 'into', 'coco', 'for', 'some', 'tea']
#
# Tokens: ['have', 'this', 'massive', 'fetish', 'for', 'tall', 'girls', 'and', 'short', 'guy', 'comparison', 'secretly', 'imagine', 'that', 'gimli', 'son', 'gloin', 'and', 'the', 'girl', 'galadriel']
#
# Tokens: ['you', 'senior', 'try', 'going', 'admu', 'early', 'the', 'morning', 'and', 'just', 'sit', 'somewhere', 'yourself', 'and', 'look', 'around', 'that', 'moment', 'peacefulness', 'you', 'get', 'flashbacks', 'all', 'the', 'memories', 'you', 'made', 'this', 'place', 'and', 'you', 'think', 'about', 'how', 'much', 'you', 'miss', 'them', 'once', 'you', 'leave', 'makes', 'you', 'sad', 'but', 'also', 'makes', 'you', 'want', 'cherish', 'the', 'time', 'you', 'have', 'left', 'here', 'you', 'think', 'the', 'people', 'you', 'want', 'have', 'lunch', 'with', 'org', 'events', 'you', 'wouldn', 'want', 'miss', 'and', 'after', 'that', 'guess', 'all', 'that', 'left', 'and', 'make', 'the', 'most', 'out']
#
# Tokens: ['note', 'ateneans', 'don', 'agree', 'with', 'the', 'many', 'students', 'being', 'regis', 'are', 'annoying', 'post', 'but', 'not', 'here', 'for', 'that', 'this', 'university', 'rank', 'discussion', 'post', 'the', 'tweet', 'that', 'became', 'popular', 'said', 'that', 'ateneo', 'was', 'just', 'rate', 'university', 'compared', 'https', 'mobile', 'twitter', 'com', 'piodu', 'status', 'know', 'joke', 'tweet', 'but', 'reminded', 'that', 'age', 'old', 'discussion', 'university', 'rankings', 'the', 'end', 'the', 'general', 'rank', 'your', 'university', 'far', 'less', 'important', 'than', 'the', 'rank', 'your', 'specific', 'course', 'minority', 'students', 'like', 'brag', 'towards', 'ateneans', 'likewise', 'minority', 'ateneans', 'brag', 'against', 'dlsu', 'and', 'but', 'the', 'university', 'rankings', 'are', 'meaningless', 'when', 'you', 'check', 'the', 'board', 'exam', 'passing', 'rate', 'your', 'specific', 'course', 'the', 'top', 'medical', 'schools', 'the', 'country', 'aren', 'even', 'from', 'the', 'big', 'course', 'rank', 'lot', 'more', 'important', 'than', 'school', 'rank', 'ofcourse', 'don', 'forget', 'about', 'mental', 'health', 'though']
#
# Tokens: ['swear', 'doods', 'sao', 'gonna', 'the', 'best', 'anime', 'the', 'end', 'the', 'season']
#
# Tokens: ['tag', 'your', 'crush', 'crush']
#
# Tokens: ['feel', 'helpless', 'right', 'now', 'hate', 'college', 'and', 'the', 'people', 'really', 'don', 'know', 'what', 'should', 'have', 'wonderful', 'girlfriend', 'and', 'still', 'feel', 'unamused', 'times', 'don', 'have', 'friends', 'nor', 'have', 'family', 'home', 'this', 'rate', 'feel', 'like', 'everyone', 'leaving', 'this', 'why', 'hate', 'people', 'try', 'hard', 'make', 'friends', 'and', 'hide', 'imperfections', 'know', 'shouldn', 'entertain', 'the', 'social', 'aspect', 'what', 'society', 'suggests', 'towards', 'how', 'things', 'the', 'world', 'should', 'but', 'find', 'myself', 'trying', 'someone', 'not', 'for', 'the', 'sake', 'having', 'people', 'stay', 'with', 'and', 'feel', 'loved', 'then', 'there', 'are', 'times', 'people', 'just', 'whisper', 'around', 'like', 'can', 'part', 'the', 'conversation']
#
# Tokens: ['really', 'want', 'break', 'diet', 'and', 'get', 'the', 'piece', 'chicken', 'nuggets', 'from', 'mcdo', 'please', 'lend', 'your', 'strength', 'calling', 'names', 'and', 'insulting', 'don', 'worry', 'masochist', 'love', 'being', 'degraded', 'make', 'hurt', 'mommies', 'and', 'daddies', 'help', 'keep', 'diet', 'thank', 'you']
#
# Tokens: ['when', 'play', 'big', 'fish', 'but', 'want', 'make', 'landi', 'rin']
#
# Tokens: ['try', 'try', 'try', 'follow', 'the', 'rules', 'break', 'every', 'one', 'them', 'with', 'girls', 'like', 'you', 'doing', 'what', 'always', 'yeah', 'crossing', 'every', 'line', 'get', 'girls', 'like', 'you', 'tripping', 'freaking', 'falling', 'over', 'girls', 'like', 'you']

# %%
model = gensim.models.Word2Vec(text_data, size=100,
                               window=10, min_count=1, workers=4)
model.train(text_data,total_examples=len(text_data),epochs=10)
# Out:
# (241724, 290270)

# %%
w = 'school'
model.wv.most_similar(positive=w)
# Out:
# [('our', 0.9999567270278931),
#  ('students', 0.9999457001686096),
#  ('while', 0.9999454021453857),
#  ('getting', 0.9999445676803589),
#  ('year', 0.9999383091926575),
#  ('has', 0.999937891960144),
#  ('than', 0.9999369978904724),
#  ('long', 0.9999369382858276),
#  ('take', 0.9999361634254456),
#  ('before', 0.9999346733093262)]

# %%
model.similarity('school', 'tangina')
# Out:
# 0.9928518

# %%
scores_list = []
index = 0

for tokens in text_data:
    print(index)
    for token in tokens:
        if token in positive_words:
            print("positive: " + token)
        elif token in negative_words:
            print("negative: " + token)
        elif token in neutral_words:
            print("neutral: " + token)
        else: 
            print("wala sa tokens: " + token)
    index += 1
# Out:
# 0
# wala sa tokens: does
# neutral: anyone
# neutral: get
# wala sa tokens: blisters
# wala sa tokens: their
# wala sa tokens: feet
# wala sa tokens: from
# neutral: walking
# neutral: much
# neutral: around
# neutral: school
# 1
# wala sa tokens: been
# wala sa tokens: few
# wala sa tokens: months
# neutral: since
# wala sa tokens: that
# neutral: whole
# neutral: sexual
# negative: harassment
# negative: scandal
# wala sa tokens: rocked
# neutral: ateneo
# wala sa tokens: the
# neutral: silence
# wala sa tokens: deafening
# wala sa tokens: some
# wala sa tokens: the
# wala sa tokens: profs
# wala sa tokens: who
# wala sa tokens: have
# wala sa tokens: been
# neutral: vocal
# wala sa tokens: about
# wala sa tokens: issues
# neutral: like
# neutral: martial
# wala sa tokens: law
# wala sa tokens: etc
# neutral: never
# neutral: spoke
# wala sa tokens: about
# wala sa tokens: this
# neutral: particular
# negative: issue
# wala sa tokens: and
# wala sa tokens: now
# wala sa tokens: they
# neutral: opening
# wala sa tokens: about
# wala sa tokens: that
# negative: fucking
# neutral: upsilon
# negative: scandal
# neutral: like
# wala sa tokens: the
# negative: worst
# negative: shit
# neutral: ever
# negative: fuck
# wala sa tokens: you
# wala sa tokens: hypocrites
# 2
# neutral: think
# wala sa tokens: the
# neutral: reason
# wala sa tokens: why
# neutral: really
# negative: hate
# neutral: filipino
# neutral: college
# wala sa tokens: not
# wala sa tokens: because
# wala sa tokens: the
# neutral: language
# wala sa tokens: but
# wala sa tokens: the
# wala sa tokens: topics
# neutral: understand
# neutral: filipino
# wala sa tokens: was
# wala sa tokens: about
# neutral: learning
# wala sa tokens: how
# neutral: speak
# wala sa tokens: deeper
# neutral: tagalog
# neutral: learning
# neutral: like
# neutral: street
# neutral: tagalog
# neutral: culture
# neutral: anything
# wala sa tokens: related
# wala sa tokens: our
# neutral: present
# neutral: times
# neutral: instead
# neutral: college
# neutral: filipino
# neutral: least
# wala sa tokens: what
# wala sa tokens: experienced
# neutral: here
# wala sa tokens: for
# wala sa tokens: had
# wala sa tokens: very
# negative: unnecessary
# neutral: lack
# positive: better
# neutral: term
# negative: useless
# wala sa tokens: topics
# wala sa tokens: lol
# neutral: filipino
# neutral: learn
# wala sa tokens: about
# neutral: girl
# wala sa tokens: falling
# positive: love
# wala sa tokens: with
# neutral: nature
# neutral: getting
# neutral: horny
# neutral: learn
# wala sa tokens: about
# wala sa tokens: the
# neutral: ancient
# wala sa tokens: filipinos
# wala sa tokens: and
# wala sa tokens: their
# neutral: super
# neutral: weird
# wala sa tokens: cultures
# wala sa tokens: and
# wala sa tokens: are
# wala sa tokens: required
# neutral: memorize
# wala sa tokens: authors
# wala sa tokens: books
# wala sa tokens: that
# neutral: probably
# neutral: never
# neutral: read
# wala sa tokens: again
# wala sa tokens: what
# wala sa tokens: trying
# neutral: say
# wala sa tokens: that
# wala sa tokens: these
# wala sa tokens: topics
# wala sa tokens: are
# wala sa tokens: not
# wala sa tokens: very
# neutral: applicable
# wala sa tokens: our
# neutral: present
# neutral: society
# neutral: sure
# neutral: can
# neutral: understand
# neutral: girl
# wala sa tokens: loves
# neutral: nature
# neutral: sure
# neutral: can
# neutral: study
# wala sa tokens: about
# wala sa tokens: the
# neutral: ancient
# neutral: filipino
# neutral: culture
# neutral: sure
# neutral: can
# neutral: memorize
# neutral: random
# wala sa tokens: authors
# neutral: names
# wala sa tokens: but
# wala sa tokens: the
# neutral: end
# wala sa tokens: after
# neutral: graduate
# neutral: sure
# wala sa tokens: all
# wala sa tokens: these
# neutral: things
# wala sa tokens: learned
# wala sa tokens: will
# wala sa tokens: forgotten
# neutral: simply
# wala sa tokens: because
# wala sa tokens: they
# negative: useless
# wala sa tokens: not
# wala sa tokens: very
# neutral: applicable
# neutral: life
# neutral: talk
# wala sa tokens: about
# wala sa tokens: authors
# wala sa tokens: memorized
# wala sa tokens: lol
# neutral: guess
# wala sa tokens: thats
# wala sa tokens: why
# neutral: people
# wala sa tokens: are
# wala sa tokens: against
# wala sa tokens: the
# neutral: filipino
# neutral: subject
# wala sa tokens: not
# wala sa tokens: because
# neutral: filipino
# wala sa tokens: sucks
# wala sa tokens: more
# wala sa tokens: because
# wala sa tokens: the
# wala sa tokens: topics
# neutral: being
# wala sa tokens: taught
# wala sa tokens: are
# neutral: really
# negative: useless
# 3
# negative: tangina
# wala sa tokens: this
# wala sa tokens: obf
# neutral: wifi
# positive: pure
# negative: shit
# wala sa tokens: all
# wala sa tokens: those
# neutral: people
# wala sa tokens: who
# neutral: say
# wala sa tokens: that
# neutral: there
# wala sa tokens: are
# wala sa tokens: thousands
# wala sa tokens: students
# neutral: here
# neutral: ateneo
# neutral: well
# neutral: guess
# wala sa tokens: what
# wala sa tokens: paid
# wala sa tokens: thousands
# wala sa tokens: for
# neutral: internet
# neutral: campus
# wala sa tokens: you
# wala sa tokens: guys
# positive: backing
# wala sa tokens: the
# neutral: team
# neutral: whatever
# wala sa tokens: are
# wala sa tokens: just
# negative: naive
# wala sa tokens: they
# wala sa tokens: are
# wala sa tokens: supposed
# wala sa tokens: have
# neutral: enough
# neutral: funds
# neutral: connect
# wala sa tokens: and
# wala sa tokens: have
# positive: stable
# neutral: internet
# neutral: everywhere
# neutral: lagi
# wala sa tokens: may
# neutral: nagdadala
# neutral: mobile
# neutral: wifi
# neutral: personal
# neutral: hotspot
# neutral: accept
# neutral: nila
# wala sa tokens: the
# neutral: school
# neutral: wifi
# wala sa tokens: not
# positive: trustable
# wala sa tokens: but
# wala sa tokens: that
# wala sa tokens: not
# positive: fair
# wala sa tokens: lol
# wala sa tokens: they
# wala sa tokens: were
# wala sa tokens: taken
# positive: advantage
# wala sa tokens: they
# wala sa tokens: paid
# wala sa tokens: have
# neutral: internet
# wala sa tokens: and
# neutral: never
# wala sa tokens: got
# wala sa tokens: what
# wala sa tokens: they
# wala sa tokens: paid
# wala sa tokens: for
# neutral: instead
# wala sa tokens: they
# wala sa tokens: had
# neutral: pay
# neutral: even
# wala sa tokens: more
# neutral: hotspot
# neutral: mobile
# neutral: wifi
# wala sa tokens: have
# neutral: wifi
# wala sa tokens: edi
# neutral: sana
# neutral: tanggalin
# wala sa tokens: nlg
# neutral: internet
# neutral: school
# neutral: tuition
# wala sa tokens: noh
# 4
# neutral: sometimes
# neutral: mood
# neutral: mood
# negative: putangina
# wala sa tokens: but
# neutral: current
# neutral: mood
# negative: putanginaaaaaa
# wala sa tokens: ugh
# neutral: life
# negative: fuck
# wala sa tokens: have
# neutral: acads
# neutral: pursue
# 5
# wala sa tokens: the
# neutral: marisol
# wala sa tokens: announcements
# neutral: really
# neutral: need
# wala sa tokens: more
# neutral: thought
# wala sa tokens: and
# positive: effort
# wala sa tokens: put
# wala sa tokens: into
# wala sa tokens: them
# neutral: honestly
# neutral: feel
# wala sa tokens: more
# wala sa tokens: discouraged
# neutral: watch
# wala sa tokens: because
# wala sa tokens: how
# neutral: hastily
# wala sa tokens: prepared
# wala sa tokens: them
# neutral: sound
# 6
# wala sa tokens: https
# wala sa tokens: tonite
# wala sa tokens: abante
# wala sa tokens: com
# neutral: ateneo
# neutral: student
# wala sa tokens: ginulpi
# wala sa tokens: hinolda
# neutral: tag
# neutral: away
# 7
# neutral: grabe
# wala sa tokens: ang
# neutral: lubak
# wala sa tokens: covered
# wala sa tokens: courts
# wala sa tokens: wtf
# 8
# neutral: free
# wala sa tokens: falling
# wala sa tokens: and
# wala sa tokens: not
# neutral: sure
# wala sa tokens: you
# neutral: there
# neutral: catch
# wala sa tokens: the
# neutral: bottom
# 9
# neutral: thought
# wala sa tokens: that
# wala sa tokens: the
# neutral: east
# neutral: carpark
# neutral: strictly
# wala sa tokens: for
# wala sa tokens: students
# wala sa tokens: only
# wala sa tokens: why
# neutral: there
# neutral: white
# neutral: innova
# wala sa tokens: parked
# neutral: beside
# wala sa tokens: with
# neutral: driver
# 10
# wala sa tokens: why
# neutral: anti
# neutral: poor
# wala sa tokens: considered
# wala sa tokens: bad
# neutral: word
# neutral: politics
# neutral: poor
# neutral: people
# neutral: squat
# wala sa tokens: your
# neutral: land
# wala sa tokens: you
# wala sa tokens: have
# neutral: legal
# neutral: right
# neutral: evict
# wala sa tokens: them
# neutral: even
# neutral: though
# neutral: anti
# neutral: poor
# neutral: poor
# neutral: people
# neutral: peddle
# wala sa tokens: goods
# wala sa tokens: and
# neutral: throw
# negative: trash
# wala sa tokens: the
# wala sa tokens: sidewalks
# wala sa tokens: you
# wala sa tokens: have
# wala sa tokens: the
# neutral: authority
# neutral: remove
# wala sa tokens: them
# neutral: even
# neutral: though
# neutral: anti
# neutral: poor
# neutral: poor
# neutral: people
# neutral: build
# neutral: squatter
# wala sa tokens: colonies
# neutral: along
# neutral: esteros
# wala sa tokens: and
# wala sa tokens: waterways
# wala sa tokens: you
# wala sa tokens: have
# wala sa tokens: the
# neutral: moral
# neutral: obligation
# neutral: relocate
# wala sa tokens: them
# neutral: even
# neutral: though
# neutral: anti
# neutral: poor
# wala sa tokens: just
# wala sa tokens: because
# neutral: something
# neutral: anti
# neutral: poor
# wala sa tokens: doesn
# neutral: automatically
# negative: mean
# wala sa tokens: bad
# neutral: fact
# wala sa tokens: some
# neutral: anti
# neutral: poor
# wala sa tokens: policies
# wala sa tokens: may
# positive: good
# wala sa tokens: for
# neutral: society
# 11
# wala sa tokens: why
# neutral: none
# wala sa tokens: the
# wala sa tokens: sockets
# wala sa tokens: the
# wala sa tokens: old
# wala sa tokens: lib
# neutral: work
# neutral: hsjsgfdhkfjklhs
# 12
# neutral: stop
# neutral: using
# neutral: mental
# neutral: health
# neutral: complain
# wala sa tokens: about
# neutral: school
# negative: difficulty
# neutral: real
# neutral: life
# neutral: much
# wala sa tokens: harder
# 13
# neutral: admufreedomwall
# wala sa tokens: and
# neutral: admufreedomwall
# neutral: feel
# wala sa tokens: you
# wala sa tokens: guys
# neutral: oldie
# wala sa tokens: the
# wala sa tokens: org
# neutral: assume
# wala sa tokens: you
# wala sa tokens: are
# wala sa tokens: referring
# wala sa tokens: and
# positive: honest
# wala sa tokens: only
# wala sa tokens: remained
# neutral: member
# wala sa tokens: because
# neutral: still
# neutral: somehow
# positive: love
# neutral: work
# wala sa tokens: and
# neutral: still
# wala sa tokens: have
# wala sa tokens: very
# wala sa tokens: very
# positive: good
# wala sa tokens: friends
# wala sa tokens: the
# wala sa tokens: org
# wala sa tokens: yes
# wala sa tokens: they
# wala sa tokens: are
# wala sa tokens: very
# neutral: cliquish
# wala sa tokens: what
# neutral: completely
# wala sa tokens: sucks
# wala sa tokens: that
# neutral: there
# neutral: sense
# negative: coldness
# wala sa tokens: between
# wala sa tokens: the
# neutral: cast
# wala sa tokens: and
# wala sa tokens: the
# neutral: production
# wala sa tokens: teams
# negative: hell
# neutral: cast
# wala sa tokens: members
# wala sa tokens: don
# neutral: even
# neutral: say
# wala sa tokens: you
# wala sa tokens: when
# wala sa tokens: you
# neutral: say
# wala sa tokens: them
# wala sa tokens: the
# neutral: theater
# wala sa tokens: for
# negative: fuck
# neutral: sake
# neutral: one
# neutral: time
# wala sa tokens: after
# wala sa tokens: just
# wala sa tokens: finished
# wala sa tokens: doing
# wala sa tokens: the
# neutral: show
# wala sa tokens: for
# wala sa tokens: lights
# wala sa tokens: stepped
# wala sa tokens: out
# wala sa tokens: and
# wala sa tokens: they
# wala sa tokens: told
# positive: thank
# wala sa tokens: you
# wala sa tokens: for
# neutral: watching
# wala sa tokens: were
# neutral: part
# wala sa tokens: the
# neutral: audience
# wala sa tokens: they
# wala sa tokens: didn
# neutral: even
# neutral: know
# wala sa tokens: been
# neutral: there
# wala sa tokens: for
# neutral: literally
# neutral: almost
# neutral: every
# neutral: show
# wala sa tokens: this
# wala sa tokens: was
# wala sa tokens: done
# neutral: times
# negative: fucking
# neutral: times
# neutral: like
# neutral: holy
# negative: shit
# neutral: niyo
# wala sa tokens: ako
# neutral: kilala
# neutral: something
# neutral: try
# neutral: say
# wala sa tokens: you
# neutral: people
# neutral: every
# negative: fucking
# neutral: time
# wala sa tokens: all
# wala sa tokens: the
# neutral: people
# wala sa tokens: who
# neutral: defend
# wala sa tokens: the
# wala sa tokens: org
# wala sa tokens: and
# neutral: say
# wala sa tokens: just
# wala sa tokens: they
# neutral: there
# wala sa tokens: for
# neutral: reason
# wala sa tokens: this
# wala sa tokens: isn
# neutral: simple
# neutral: problem
# neutral: there
# neutral: problem
# wala sa tokens: with
# wala sa tokens: how
# wala sa tokens: the
# wala sa tokens: org
# wala sa tokens: has
# wala sa tokens: been
# neutral: systematically
# neutral: there
# wala sa tokens: lot
# negative: nepotism
# wala sa tokens: some
# neutral: people
# neutral: get
# wala sa tokens: positions
# wala sa tokens: that
# wala sa tokens: they
# wala sa tokens: don
# neutral: deserve
# wala sa tokens: but
# wala sa tokens: only
# neutral: get
# wala sa tokens: because
# wala sa tokens: they
# wala sa tokens: friends
# wala sa tokens: with
# wala sa tokens: the
# wala sa tokens: pms
# wala sa tokens: for
# neutral: example
# wala sa tokens: once
# wala sa tokens: applied
# wala sa tokens: the
# neutral: part
# neutral: mainstage
# neutral: second
# neutral: semester
# neutral: production
# neutral: prior
# wala sa tokens: applying
# wala sa tokens: had
# wala sa tokens: done
# wala sa tokens: org
# wala sa tokens: productions
# wala sa tokens: productions
# wala sa tokens: for
# neutral: another
# wala sa tokens: org
# wala sa tokens: and
# neutral: even
# wala sa tokens: done
# positive: professional
# neutral: work
# neutral: outside
# neutral: ateneo
# neutral: basically
# wala sa tokens: and
# wala sa tokens: not
# neutral: boast
# wala sa tokens: was
# wala sa tokens: the
# neutral: one
# wala sa tokens: for
# wala sa tokens: the
# neutral: job
# wala sa tokens: didn
# neutral: get
# neutral: instead
# neutral: someone
# wala sa tokens: who
# wala sa tokens: was
# neutral: close
# wala sa tokens: with
# wala sa tokens: the
# wala sa tokens: and
# neutral: whose
# wala sa tokens: only
# neutral: experience
# wala sa tokens: technicals
# wala sa tokens: was
# neutral: working
# neutral: set
# neutral: props
# wala sa tokens: got
# wala sa tokens: the
# neutral: job
# wala sa tokens: was
# positive: incredibly
# wala sa tokens: frustrating
# wala sa tokens: that
# neutral: being
# wala sa tokens: said
# wala sa tokens: the
# wala sa tokens: two
# wala sa tokens: newbies
# wala sa tokens: who
# wala sa tokens: have
# wala sa tokens: spoken
# wala sa tokens: out
# neutral: implore
# wala sa tokens: you
# neutral: stay
# wala sa tokens: not
# wala sa tokens: because
# wala sa tokens: the
# neutral: people
# neutral: stay
# wala sa tokens: for
# wala sa tokens: the
# neutral: craft
# neutral: can
# wala sa tokens: denied
# wala sa tokens: that
# wala sa tokens: said
# wala sa tokens: org
# neutral: still
# wala sa tokens: has
# positive: great
# wala sa tokens: productions
# neutral: despite
# wala sa tokens: lot
# neutral: backstage
# negative: frustration
# wala sa tokens: and
# wala sa tokens: the
# wala sa tokens: performers
# wala sa tokens: are
# neutral: still
# neutral: among
# wala sa tokens: the
# positive: best
# wala sa tokens: the
# neutral: school
# wala sa tokens: and
# neutral: even
# wala sa tokens: the
# neutral: philippines
# positive: love
# wala sa tokens: your
# neutral: work
# wala sa tokens: doesn
# negative: mean
# wala sa tokens: you
# wala sa tokens: have
# positive: love
# wala sa tokens: the
# neutral: people
# neutral: along
# wala sa tokens: the
# wala sa tokens: way
# neutral: screw
# wala sa tokens: them
# 14
# wala sa tokens: dreamt
# wala sa tokens: that
# wala sa tokens: this
# neutral: girl
# wala sa tokens: from
# wala sa tokens: org
# wala sa tokens: and
# wala sa tokens: were
# neutral: making
# neutral: momol
# wala sa tokens: and
# neutral: weird
# wala sa tokens: and
# wala sa tokens: don
# neutral: want
# neutral: like
# wala sa tokens: her
# wala sa tokens: that
# wala sa tokens: way
# neutral: cause
# wala sa tokens: she
# wala sa tokens: the
# neutral: first
# neutral: real
# neutral: friend
# wala sa tokens: had
# wala sa tokens: that
# wala sa tokens: org
# 15
# wala sa tokens: what
# wala sa tokens: the
# neutral: least
# negative: painful
# wala sa tokens: way
# negative: kill
# wala sa tokens: yourself
# neutral: wanna
# negative: die
# wala sa tokens: but
# neutral: like
# wala sa tokens: just
# neutral: dont
# neutral: want
# neutral: inflict
# wala sa tokens: too
# neutral: much
# neutral: physical
# negative: pain
# wala sa tokens: myself
# wala sa tokens: existing
# wala sa tokens: just
# wala sa tokens: too
# neutral: much
# neutral: nowadays
# neutral: help
# wala sa tokens: bro
# wala sa tokens: out
# neutral: giving
# wala sa tokens: suggestions
# positive: hehe
# 16
# neutral: okay
# wala sa tokens: haven
# wala sa tokens: had
# wala sa tokens: any
# neutral: sleep
# wala sa tokens: and
# wala sa tokens: was
# neutral: wandering
# neutral: around
# neutral: ateneo
# neutral: playing
# neutral: pokemon
# wala sa tokens: when
# wala sa tokens: was
# wala sa tokens: participating
# neutral: raid
# wala sa tokens: with
# neutral: someone
# neutral: else
# wala sa tokens: finished
# wala sa tokens: the
# neutral: raid
# wala sa tokens: and
# wala sa tokens: they
# wala sa tokens: seemed
# neutral: super
# positive: nice
# wala sa tokens: and
# wala sa tokens: they
# wala sa tokens: tried
# neutral: talk
# wala sa tokens: but
# wala sa tokens: was
# neutral: super
# wala sa tokens: zoned
# wala sa tokens: out
# wala sa tokens: and
# wala sa tokens: was
# neutral: super
# neutral: slow
# neutral: listening
# neutral: sorry
# positive: hope
# wala sa tokens: didn
# negative: offend
# wala sa tokens: but
# positive: thank
# wala sa tokens: you
# wala sa tokens: for
# neutral: helping
# neutral: get
# wala sa tokens: the
# neutral: mareep
# wala sa tokens: and
# wala sa tokens: applied
# neutral: join
# wala sa tokens: the
# neutral: group
# wala sa tokens: you
# wala sa tokens: asked
# neutral: think
# 17
# wala sa tokens: any
# wala sa tokens: tips
# wala sa tokens: how
# neutral: make
# neutral: landi
# wala sa tokens: with
# neutral: girl
# wala sa tokens: you
# wala sa tokens: not
# neutral: close
# wala sa tokens: with
# wala sa tokens: but
# wala sa tokens: you
# neutral: want
# 18
# neutral: admufreedomwall
# wala sa tokens: heard
# wala sa tokens: that
# neutral: quite
# neutral: number
# wala sa tokens: them
# wala sa tokens: graduated
# wala sa tokens: from
# wala sa tokens: ahs
# 19
# wala sa tokens: which
# positive: better
# neutral: dell
# wala sa tokens: xps
# neutral: macbook
# wala sa tokens: pro
# neutral: need
# wala sa tokens: them
# wala sa tokens: opinions
# 20
# neutral: want
# positive: love
# 21
# wala sa tokens: when
# wala sa tokens: you
# wala sa tokens: just
# neutral: wanna
# neutral: get
# wala sa tokens: the
# neutral: sakamura
# neutral: stall
# neutral: gonz
# wala sa tokens: but
# wala sa tokens: the
# neutral: line
# neutral: sutra
# neutral: long
# neutral: abot
# neutral: hanggang
# negative: hunger
# neutral: buster
# wala sa tokens: and
# wala sa tokens: you
# neutral: can
# neutral: get
# wala sa tokens: through
# 22
# wala sa tokens: were
# neutral: living
# positive: peacefully
# wala sa tokens: the
# neutral: beginning
# wala sa tokens: until
# neutral: people
# wala sa tokens: from
# neutral: outside
# wala sa tokens: these
# wala sa tokens: islands
# wala sa tokens: came
# wala sa tokens: and
# wala sa tokens: fucked
# neutral: many
# neutral: ways
# neutral: ironic
# neutral: though
# wala sa tokens: the
# neutral: end
# wala sa tokens: all
# wala sa tokens: wouldn
# wala sa tokens: foreigners
# wala sa tokens: but
# wala sa tokens: our
# wala sa tokens: very
# wala sa tokens: own
# neutral: brother
# neutral: fellow
# neutral: filipino
# wala sa tokens: who
# neutral: would
# neutral: screw
# wala sa tokens: over
# wala sa tokens: and
# neutral: sell
# wala sa tokens: out
# 23
# neutral: let
# wala sa tokens: just
# neutral: remember
# wala sa tokens: that
# neutral: there
# wala sa tokens: was
# neutral: point
# neutral: history
# wala sa tokens: where
# wala sa tokens: were
# wala sa tokens: privileged
# wala sa tokens: have
# neutral: something
# positive: beautiful
# neutral: nation
# neutral: land
# neutral: could
# neutral: call
# neutral: home
# neutral: years
# wala sa tokens: from
# wala sa tokens: now
# wala sa tokens: our
# neutral: grandkids
# wala sa tokens: wouldn
# wala sa tokens: have
# wala sa tokens: the
# wala sa tokens: same
# neutral: privilege
# wala sa tokens: this
# neutral: archipelago
# wala sa tokens: will
# neutral: province
# neutral: another
# neutral: state
# wala sa tokens: but
# wala sa tokens: this
# neutral: archipelago
# wala sa tokens: the
# neutral: philippines
# wala sa tokens: will
# neutral: cease
# neutral: exist
# neutral: every
# neutral: concept
# neutral: notion
# neutral: filipino
# wala sa tokens: will
# neutral: cease
# neutral: exist
# wala sa tokens: when
# wala sa tokens: your
# wala sa tokens: grandchildren
# wala sa tokens: you
# wala sa tokens: they
# wala sa tokens: will
# neutral: ask
# wala sa tokens: you
# wala sa tokens: what
# wala sa tokens: was
# neutral: like
# neutral: filipino
# wala sa tokens: and
# wala sa tokens: you
# wala sa tokens: will
# neutral: tell
# wala sa tokens: them
# wala sa tokens: your
# wala sa tokens: stories
# wala sa tokens: with
# neutral: tears
# wala sa tokens: your
# neutral: eyes
# neutral: knowing
# wala sa tokens: that
# neutral: there
# wala sa tokens: was
# neutral: moment
# neutral: history
# wala sa tokens: where
# neutral: nation
# wala sa tokens: called
# wala sa tokens: the
# neutral: philippines
# wala sa tokens: existed
# wala sa tokens: and
# wala sa tokens: you
# wala sa tokens: were
# neutral: part
# wala sa tokens: that
# neutral: history
# 24
# negative: tangina
# neutral: naman
# neutral: kahit
# negative: winasak
# wala sa tokens: ako
# neutral: kahit
# neutral: araw
# neutral: araw
# neutral: akong
# neutral: namamatay
# neutral: dahil
# neutral: kahit
# wala sa tokens: ang
# neutral: sakit
# neutral: sakit
# neutral: talaga
# neutral: grabe
# neutral: sobrang
# neutral: lala
# neutral: bakit
# neutral: hindi
# wala sa tokens: rin
# neutral: nagbabago
# neutral: pakiramdam
# neutral: para
# wala sa tokens: iyo
# 25
# wala sa tokens: the
# wala sa tokens: only
# neutral: atenean
# negative: natatakot
# neutral: nangyayari
# neutral: inside
# wala sa tokens: upd
# neutral: like
# wala sa tokens: this
# wala sa tokens: guys
# wala sa tokens: from
# neutral: downsilon
# neutral: can
# negative: kill
# neutral: people
# wala sa tokens: with
# wala sa tokens: guns
# neutral: without
# neutral: anyone
# wala sa tokens: noticing
# wala sa tokens: them
# neutral: someone
# neutral: please
# neutral: stop
# wala sa tokens: those
# negative: barbaric
# wala sa tokens: pigs
# 26
# neutral: miss
# neutral: back
# neutral: home
# wala sa tokens: bad
# wala sa tokens: been
# neutral: restless
# wala sa tokens: for
# wala sa tokens: the
# neutral: past
# neutral: couple
# wala sa tokens: weeks
# wala sa tokens: and
# neutral: can
# neutral: wait
# neutral: home
# wala sa tokens: been
# neutral: super
# negative: nervous
# wala sa tokens: and
# neutral: fidgety
# neutral: ever
# neutral: since
# wala sa tokens: she
# wala sa tokens: stopped
# wala sa tokens: replying
# wala sa tokens: messages
# neutral: often
# neutral: tell
# wala sa tokens: myself
# wala sa tokens: she
# neutral: busy
# wala sa tokens: she
# neutral: studying
# wala sa tokens: she
# wala sa tokens: with
# wala sa tokens: her
# wala sa tokens: friends
# wala sa tokens: you
# neutral: gotta
# neutral: give
# wala sa tokens: her
# wala sa tokens: some
# neutral: space
# wala sa tokens: man
# wala sa tokens: but
# neutral: matter
# wala sa tokens: how
# negative: hard
# neutral: try
# wala sa tokens: that
# negative: annoying
# neutral: thought
# wala sa tokens: lingers
# neutral: mind
# wala sa tokens: that
# wala sa tokens: she
# wala sa tokens: isn
# wala sa tokens: interested
# neutral: anymore
# neutral: can
# neutral: even
# neutral: tell
# wala sa tokens: her
# wala sa tokens: how
# neutral: feel
# wala sa tokens: because
# wala sa tokens: she
# neutral: rarely
# neutral: ever
# wala sa tokens: replies
# wala sa tokens: and
# wala sa tokens: yet
# neutral: tell
# wala sa tokens: myself
# wala sa tokens: she
# neutral: busy
# wala sa tokens: with
# wala sa tokens: academics
# neutral: give
# wala sa tokens: her
# neutral: space
# wala sa tokens: and
# wala sa tokens: will
# wala sa tokens: all
# neutral: work
# wala sa tokens: out
# wala sa tokens: the
# neutral: end
# positive: hope
# 27
# wala sa tokens: hayss
# wala sa tokens: this
# neutral: group
# 28
# neutral: take
# wala sa tokens: photos
# wala sa tokens: the
# neutral: carrie
# neutral: photographer
# wala sa tokens: but
# neutral: photography
# wala sa tokens: isn
# wala sa tokens: allowed
# wala sa tokens: daw
# wala sa tokens: the
# neutral: theater
# 29
# neutral: people
# wala sa tokens: trying
# neutral: save
# wala sa tokens: endangered
# neutral: species
# neutral: want
# neutral: see
# wala sa tokens: the
# wala sa tokens: animals
# negative: fuck
# 30
# wala sa tokens: what
# wala sa tokens: expected
# wala sa tokens: from
# neutral: filipino
# wala sa tokens: classes
# positive: great
# neutral: class
# wala sa tokens: that
# wala sa tokens: focuses
# neutral: filipino
# neutral: culture
# neutral: linguistics
# neutral: history
# wala sa tokens: and
# neutral: modern
# neutral: politics
# wala sa tokens: educating
# wala sa tokens: students
# wala sa tokens: with
# neutral: solid
# neutral: information
# neutral: worthy
# neutral: one
# wala sa tokens: the
# neutral: top
# wala sa tokens: schools
# wala sa tokens: the
# neutral: country
# wala sa tokens: what
# wala sa tokens: got
# neutral: teacher
# wala sa tokens: which
# wala sa tokens: uses
# neutral: hour
# neutral: rant
# wala sa tokens: about
# wala sa tokens: that
# wala sa tokens: you
# neutral: gotta
# neutral: work
# neutral: work
# neutral: gatorade
# neutral: saying
# wala sa tokens: that
# negative: brainwashing
# neutral: people
# neutral: work
# neutral: minimum
# neutral: wage
# neutral: job
# wala sa tokens: then
# negative: die
# wala sa tokens: the
# neutral: capitalist
# neutral: system
# neutral: instead
# wala sa tokens: you
# neutral: know
# wala sa tokens: just
# neutral: being
# wala sa tokens: trying
# neutral: target
# neutral: specific
# neutral: audience
# wala sa tokens: athletes
# wala sa tokens: that
# neutral: relate
# wala sa tokens: the
# neutral: routine
# neutral: training
# wala sa tokens: that
# wala sa tokens: athletes
# wala sa tokens: the
# neutral: video
# neutral: endure
# 31
# wala sa tokens: should
# neutral: give
# neutral: another
# neutral: chance
# neutral: want
# wala sa tokens: too
# neutral: know
# wala sa tokens: loves
# wala sa tokens: but
# wala sa tokens: don
# neutral: know
# neutral: worth
# neutral: anymore
# negative: huhhuhu
# 32
# positive: favorite
# neutral: pokemon
# neutral: game
# neutral: honestly
# neutral: pokemon
# neutral: snap
# wala sa tokens: was
# neutral: weird
# wala sa tokens: but
# wala sa tokens: they
# neutral: sorta
# wala sa tokens: added
# wala sa tokens: the
# neutral: concept
# neutral: pokemon
# neutral: sumo
# 33
# neutral: always
# wala sa tokens: prayed
# wala sa tokens: that
# neutral: never
# neutral: get
# neutral: anybody
# neutral: pregnant
# wala sa tokens: before
# wala sa tokens: got
# positive: decent
# neutral: job
# neutral: year
# neutral: later
# neutral: found
# wala sa tokens: out
# wala sa tokens: was
# neutral: gay
# positive: prayer
# wala sa tokens: answered
# neutral: guess
# 34
# neutral: admufreedomwall
# neutral: anon
# wala sa tokens: used
# neutral: newbie
# wala sa tokens: that
# wala sa tokens: org
# wala sa tokens: too
# wala sa tokens: and
# wala sa tokens: had
# wala sa tokens: the
# negative: worst
# neutral: experience
# neutral: life
# neutral: felt
# wala sa tokens: was
# neutral: working
# wala sa tokens: with
# neutral: people
# wala sa tokens: with
# wala sa tokens: the
# neutral: primary
# neutral: intention
# wala sa tokens: receiving
# neutral: attention
# wala sa tokens: and
# neutral: high
# neutral: dose
# neutral: fame
# wala sa tokens: was
# wala sa tokens: disgusting
# neutral: there
# wala sa tokens: were
# positive: good
# neutral: people
# neutral: sure
# wala sa tokens: but
# wala sa tokens: the
# neutral: whole
# neutral: working
# neutral: environment
# wala sa tokens: was
# wala sa tokens: terrifying
# neutral: working
# wala sa tokens: with
# wala sa tokens: them
# neutral: set
# wala sa tokens: the
# neutral: mood
# wala sa tokens: for
# neutral: freshie
# neutral: life
# neutral: back
# wala sa tokens: then
# wala sa tokens: and
# neutral: can
# neutral: say
# wala sa tokens: dreaded
# neutral: life
# positive: thankful
# wala sa tokens: have
# wala sa tokens: gotten
# wala sa tokens: out
# neutral: still
# neutral: wish
# wala sa tokens: they
# neutral: would
# neutral: change
# wala sa tokens: for
# neutral: despite
# neutral: everything
# neutral: remain
# positive: hopeful
# wala sa tokens: for
# wala sa tokens: them
# wala sa tokens: this
# neutral: year
# wala sa tokens: newbies
# neutral: save
# wala sa tokens: yourselves
# wala sa tokens: you
# neutral: choose
# neutral: stay
# neutral: save
# wala sa tokens: the
# wala sa tokens: org
# wala sa tokens: and
# neutral: change
# wala sa tokens: for
# wala sa tokens: the
# positive: better
# wala sa tokens: for
# wala sa tokens: your
# neutral: craft
# wala sa tokens: not
# wala sa tokens: for
# wala sa tokens: your
# neutral: reputation
# 35
# wala sa tokens: the
# wala sa tokens: only
# neutral: one
# wala sa tokens: who
# wala sa tokens: not
# neutral: close
# wala sa tokens: with
# neutral: block
# wala sa tokens: after
# neutral: looking
# neutral: aegis
# neutral: block
# neutral: photoshoots
# wala sa tokens: they
# neutral: look
# neutral: close
# wala sa tokens: each
# wala sa tokens: other
# 36
# wala sa tokens: wow
# wala sa tokens: such
# neutral: strongman
# neutral: leader
# positive: love
# neutral: jinping
# 37
# neutral: admufreedomwall
# neutral: alam
# neutral: yung
# wala sa tokens: mas
# negative: masakit
# neutral: yung
# neutral: kinuwento
# positive: kaibigan
# neutral: crush
# wala sa tokens: naging
# neutral: sila
# 38
# negative: ugly
# wala sa tokens: and
# wala sa tokens: this
# wala sa tokens: makes
# negative: sad
# 39
# wala sa tokens: just
# neutral: really
# neutral: really
# wala sa tokens: wanted
# neutral: say
# negative: fuckinnnnng
# negative: sad
# wala sa tokens: and
# neutral: one
# neutral: would
# neutral: ever
# neutral: think
# wala sa tokens: the
# neutral: one
# neutral: send
# wala sa tokens: this
# neutral: cause
# neutral: everyone
# wala sa tokens: thinks
# neutral: always
# positive: happy
# 40
# neutral: empire
# wala sa tokens: toppled
# wala sa tokens: its
# wala sa tokens: enemies
# neutral: can
# neutral: rise
# wala sa tokens: again
# wala sa tokens: but
# neutral: one
# wala sa tokens: that
# wala sa tokens: crumbles
# wala sa tokens: from
# neutral: within
# wala sa tokens: that
# negative: dead
# neutral: forever
# neutral: helmut
# neutral: zemo
# positive: civil
# wala sa tokens: war
# 41
# wala sa tokens: oaa
# neutral: ask
# neutral: lang
# neutral: kelan
# neutral: dadating
# neutral: allowance
# positive: thanks
# 42
# wala sa tokens: don
# neutral: slam
# wala sa tokens: for
# neutral: musical
# wala sa tokens: preferences
# wala sa tokens: yes
# neutral: diehard
# neutral: rock
# neutral: roll
# neutral: listener
# wala sa tokens: who
# neutral: acts
# neutral: rebellious
# wala sa tokens: but
# neutral: can
# wala sa tokens: you
# neutral: please
# neutral: please
# neutral: please
# neutral: shut
# wala sa tokens: the
# negative: fuck
# wala sa tokens: you
# wala sa tokens: have
# neutral: nothing
# positive: nice
# neutral: say
# wala sa tokens: about
# neutral: music
# neutral: sorry
# neutral: act
# neutral: really
# negative: raunchy
# neutral: towards
# neutral: modern
# neutral: pop
# neutral: music
# neutral: times
# wala sa tokens: but
# neutral: sometimes
# wala sa tokens: all
# wala sa tokens: about
# wala sa tokens: the
# neutral: substance
# wala sa tokens: that
# wala sa tokens: the
# neutral: music
# wala sa tokens: gives
# wala sa tokens: not
# wala sa tokens: the
# neutral: popularity
# wala sa tokens: and
# neutral: hype
# wala sa tokens: that
# wala sa tokens: all
# wala sa tokens: those
# neutral: whiffle
# wala sa tokens: waffles
# wala sa tokens: out
# neutral: there
# neutral: try
# wala sa tokens: rub
# wala sa tokens: our
# wala sa tokens: faces
# wala sa tokens: with
# neutral: deal
# wala sa tokens: with
# wala sa tokens: that
# 43
# neutral: please
# neutral: subscribe
# neutral: pewdiepie
# wala sa tokens: doing
# neutral: part
# 44
# positive: love
# neutral: class
# neutral: much
# wala sa tokens: but
# neutral: sometimes
# wala sa tokens: just
# neutral: feel
# neutral: like
# wala sa tokens: they
# neutral: like
# neutral: vanilla
# wala sa tokens: ice
# neutral: cream
# wala sa tokens: and
# wala sa tokens: friends
# wala sa tokens: and
# neutral: small
# neutral: friend
# neutral: group
# wala sa tokens: are
# neutral: like
# wala sa tokens: the
# wala sa tokens: fun
# wala sa tokens: flavors
# neutral: like
# wala sa tokens: cookies
# wala sa tokens: and
# neutral: cream
# neutral: rocky
# neutral: road
# wala sa tokens: etc
# wala sa tokens: the
# neutral: rest
# wala sa tokens: them
# neutral: can
# wala sa tokens: just
# wala sa tokens: such
# negative: fucking
# negative: bore
# neutral: like
# wala sa tokens: don
# negative: hate
# wala sa tokens: them
# wala sa tokens: just
# neutral: feel
# neutral: like
# neutral: sometimes
# neutral: wanna
# neutral: say
# neutral: something
# neutral: crazy
# wala sa tokens: and
# neutral: outlandish
# wala sa tokens: but
# wala sa tokens: because
# wala sa tokens: their
# positive: sweet
# neutral: vanilla
# neutral: nature
# wala sa tokens: they
# wala sa tokens: just
# positive: smile
# wala sa tokens: and
# neutral: say
# positive: fine
# wala sa tokens: and
# neutral: pretend
# neutral: never
# wala sa tokens: happened
# neutral: right
# wala sa tokens: now
# wala sa tokens: just
# wala sa tokens: trying
# wala sa tokens: friends
# wala sa tokens: with
# wala sa tokens: them
# wala sa tokens: because
# wala sa tokens: they
# neutral: really
# wala sa tokens: are
# positive: genuine
# wala sa tokens: and
# positive: nice
# neutral: people
# wala sa tokens: they
# neutral: can
# wala sa tokens: just
# neutral: bland
# negative: boring
# wala sa tokens: and
# neutral: basic
# wala sa tokens: most
# wala sa tokens: the
# neutral: time
# 45
# wala sa tokens: was
# negative: bobo
# wala sa tokens: way
# neutral: back
# neutral: ateneo
# neutral: days
# wala sa tokens: compared
# wala sa tokens: classmates
# wala sa tokens: they
# neutral: keep
# wala sa tokens: having
# wala sa tokens: grades
# neutral: like
# wala sa tokens: and
# wala sa tokens: and
# wala sa tokens: ako
# neutral: naman
# neutral: panay
# neutral: really
# neutral: thought
# wala sa tokens: was
# wala sa tokens: not
# wala sa tokens: gonna
# neutral: graduate
# neutral: pero
# negative: puta
# wala sa tokens: did
# wala sa tokens: and
# wala sa tokens: now
# neutral: working
# wala sa tokens: and
# neutral: job
# wala sa tokens: pays
# positive: great
# wala sa tokens: wag
# neutral: kayo
# neutral: susuko
# wala sa tokens: guys
# wala sa tokens: laging
# wala sa tokens: may
# neutral: light
# wala sa tokens: the
# neutral: end
# neutral: tunnel
# neutral: kung
# wala sa tokens: ano
# wala sa tokens: man
# wala sa tokens: yan
# neutral: dinadanan
# 46
# neutral: anyone
# neutral: know
# neutral: pokemon
# neutral: music
# wala sa tokens: from
# wala sa tokens: gen
# wala sa tokens: gen
# neutral: maybe
# neutral: even
# wala sa tokens: gen
# wala sa tokens: and
# 47
# positive: happy
# neutral: thanksgiving
# neutral: everyone
# positive: hope
# wala sa tokens: enjoyed
# wala sa tokens: your
# neutral: turkey
# wala sa tokens: and
# wala sa tokens: pies
# 48
# negative: hate
# negative: fraudulent
# wala sa tokens: misleading
# wala sa tokens: networking
# neutral: people
# wala sa tokens: this
# neutral: post
# wala sa tokens: was
# wala sa tokens: made
# neutral: warn
# neutral: people
# wala sa tokens: about
# wala sa tokens: networking
# wala sa tokens: and
# wala sa tokens: how
# negative: fraudulent
# wala sa tokens: their
# wala sa tokens: reps
# wala sa tokens: are
# neutral: know
# wala sa tokens: not
# positive: good
# neutral: generalize
# wala sa tokens: but
# neutral: there
# wala sa tokens: was
# wala sa tokens: this
# neutral: brand
# wala sa tokens: rhymes
# wala sa tokens: with
# neutral: muskeen
# wala sa tokens: who
# wala sa tokens: invited
# wala sa tokens: for
# neutral: meeting
# wala sa tokens: about
# neutral: job
# neutral: opening
# neutral: field
# neutral: already
# neutral: skeptical
# wala sa tokens: about
# wala sa tokens: told
# wala sa tokens: them
# wala sa tokens: that
# neutral: think
# wala sa tokens: about
# neutral: joke
# wala sa tokens: for
# negative: worrying
# neutral: come
# wala sa tokens: off
# negative: impolite
# neutral: say
# wala sa tokens: when
# wala sa tokens: the
# wala sa tokens: day
# wala sa tokens: came
# wala sa tokens: that
# wala sa tokens: followed
# wala sa tokens: for
# neutral: confirmation
# neutral: straight
# wala sa tokens: asked
# wala sa tokens: the
# neutral: person
# wala sa tokens: was
# neutral: network
# neutral: marketing
# neutral: event
# neutral: literally
# wala sa tokens: said
# wala sa tokens: that
# neutral: wasnt
# neutral: believing
# wala sa tokens: him
# wala sa tokens: went
# wala sa tokens: the
# neutral: meeting
# wala sa tokens: because
# wala sa tokens: trusted
# wala sa tokens: him
# wala sa tokens: that
# wala sa tokens: where
# wala sa tokens: made
# wala sa tokens: the
# wala sa tokens: biggest
# negative: mistake
# wala sa tokens: the
# wala sa tokens: speakers
# wala sa tokens: the
# neutral: event
# wala sa tokens: were
# neutral: going
# wala sa tokens: about
# wala sa tokens: how
# neutral: network
# neutral: marketing
# wala sa tokens: was
# wala sa tokens: the
# positive: best
# wala sa tokens: way
# neutral: earn
# neutral: money
# wala sa tokens: ugh
# wala sa tokens: fuq
# wala sa tokens: ive
# wala sa tokens: been
# negative: lied
# wala sa tokens: and
# neutral: fell
# wala sa tokens: for
# neutral: already
# wala sa tokens: laughing
# wala sa tokens: myself
# wala sa tokens: for
# wala sa tokens: falling
# wala sa tokens: for
# wala sa tokens: this
# wala sa tokens: but
# neutral: sharing
# wala sa tokens: this
# neutral: experience
# wala sa tokens: all
# neutral: cautionary
# neutral: tale
# neutral: avoid
# neutral: people
# neutral: messaging
# wala sa tokens: you
# wala sa tokens: about
# neutral: business
# neutral: venture
# neutral: business
# neutral: opportunity
# neutral: take
# neutral: everything
# wala sa tokens: with
# neutral: grain
# neutral: salt
# wala sa tokens: they
# wala sa tokens: won
# neutral: tell
# wala sa tokens: you
# wala sa tokens: what
# neutral: brand
# wala sa tokens: they
# neutral: working
# wala sa tokens: for
# wala sa tokens: don
# negative: waste
# wala sa tokens: more
# neutral: time
# wala sa tokens: entertaining
# wala sa tokens: these
# negative: shady
# neutral: people
# wala sa tokens: you
# neutral: already
# neutral: think
# wala sa tokens: they
# negative: dodgey
# positive: trust
# wala sa tokens: your
# wala sa tokens: gut
# wala sa tokens: you
# neutral: can
# neutral: find
# wala sa tokens: them
# wala sa tokens: the
# neutral: first
# neutral: page
# neutral: google
# wala sa tokens: don
# neutral: even
# neutral: think
# wala sa tokens: about
# neutral: network
# wala sa tokens: marketers
# neutral: pyramid
# neutral: scheme
# wala sa tokens: scammers
# neutral: make
# neutral: people
# wala sa tokens: the
# neutral: higher
# neutral: wrungs
# wala sa tokens: richer
# wala sa tokens: they
# wala sa tokens: stigmatized
# wala sa tokens: for
# neutral: reason
# wala sa tokens: all
# wala sa tokens: these
# neutral: skincare
# neutral: health
# neutral: pharma
# neutral: things
# wala sa tokens: may
# wala sa tokens: the
# neutral: bread
# wala sa tokens: and
# neutral: butter
# wala sa tokens: some
# wala sa tokens: but
# positive: hope
# wala sa tokens: these
# neutral: people
# neutral: dont
# neutral: lie
# neutral: people
# wala sa tokens: just
# wala sa tokens: they
# neutral: can
# neutral: get
# wala sa tokens: their
# wala sa tokens: way
# wala sa tokens: not
# negative: impolite
# neutral: step
# neutral: away
# wala sa tokens: when
# wala sa tokens: you
# neutral: realize
# negative: fraudulent
# neutral: invitation
# wala sa tokens: that
# neutral: hours
# neutral: life
# wala sa tokens: that
# wala sa tokens: won
# neutral: get
# neutral: back
# wala sa tokens: how
# wala sa tokens: these
# neutral: people
# neutral: sleep
# 49
# negative: angry
# neutral: class
# wala sa tokens: for
# wala sa tokens: having
# neutral: swear
# wala sa tokens: jar
# 50
# neutral: almost
# wala sa tokens: the
# neutral: end
# wala sa tokens: the
# wala sa tokens: sem
# neutral: life
# neutral: mood
# 51
# neutral: there
# wala sa tokens: these
# neutral: group
# neutral: people
# wala sa tokens: who
# wala sa tokens: will
# neutral: invite
# wala sa tokens: you
# neutral: marketing
# neutral: event
# neutral: octagon
# neutral: plaza
# neutral: ortigas
# wala sa tokens: but
# neutral: wait
# neutral: people
# negative: scam
# wala sa tokens: because
# wala sa tokens: all
# wala sa tokens: that
# neutral: making
# neutral: think
# wala sa tokens: networking
# positive: best
# neutral: marketing
# wala sa tokens: for
# wala sa tokens: the
# neutral: sole
# neutral: intention
# wala sa tokens: blinding
# wala sa tokens: you
# neutral: sell
# wala sa tokens: their
# wala sa tokens: products
# wala sa tokens: this
# wala sa tokens: not
# wala sa tokens: some
# neutral: dark
# neutral: capitalist
# negative: shit
# neutral: pyramid
# neutral: scheme
# wala sa tokens: idk
# wala sa tokens: what
# 52
# negative: fuck
# negative: shit
# negative: bitch
# negative: gago
# negative: putangina
# neutral: sorry
# wala sa tokens: just
# neutral: letting
# wala sa tokens: out
# wala sa tokens: swears
# wala sa tokens: that
# neutral: can
# neutral: say
# wala sa tokens: because
# neutral: class
# wala sa tokens: had
# wala sa tokens: have
# wala sa tokens: the
# negative: shitty
# neutral: idea
# wala sa tokens: having
# neutral: swear
# wala sa tokens: jar
# neutral: know
# wala sa tokens: for
# wala sa tokens: the
# neutral: class
# neutral: funds
# wala sa tokens: but
# neutral: would
# positive: happily
# neutral: donate
# wala sa tokens: the
# neutral: class
# neutral: funds
# neutral: can
# wala sa tokens: just
# neutral: let
# wala sa tokens: out
# wala sa tokens: emotions
# negative: goddammit
# 53
# neutral: looking
# wala sa tokens: for
# neutral: date
# neutral: lantern
# neutral: parade
# neutral: isko
# neutral: here
# neutral: sisiguraduhin
# neutral: kong
# neutral: hindi
# negative: malungkot
# wala sa tokens: ang
# neutral: pasko
# neutral: sasamahan
# neutral: kitang
# wala sa tokens: mag
# neutral: simbang
# neutral: gabi
# neutral: ateneo
# neutral: pwede
# wala sa tokens: rin
# 54
# wala sa tokens: you
# wala sa tokens: been
# positive: good
# neutral: friend
# wala sa tokens: who
# wala sa tokens: treats
# neutral: well
# wala sa tokens: but
# wala sa tokens: the
# neutral: thing
# neutral: nothing
# neutral: special
# wala sa tokens: you
# wala sa tokens: all
# wala sa tokens: realized
# wala sa tokens: just
# wala sa tokens: how
# wala sa tokens: you
# wala sa tokens: are
# wala sa tokens: with
# neutral: everyone
# wala sa tokens: but
# wala sa tokens: the
# neutral: thing
# neutral: one
# neutral: ever
# wala sa tokens: treated
# neutral: like
# wala sa tokens: this
# neutral: sorry
# wala sa tokens: but
# neutral: can
# neutral: help
# wala sa tokens: you
# neutral: special
# 55
# neutral: poor
# neutral: guy
# wala sa tokens: wasn
# neutral: able
# wala sa tokens: his
# neutral: retreat
# wala sa tokens: because
# neutral: something
# negative: stupid
# wala sa tokens: and
# neutral: feel
# neutral: like
# neutral: partly
# neutral: responsible
# wala sa tokens: because
# neutral: could
# wala sa tokens: have
# wala sa tokens: done
# neutral: something
# wala sa tokens: but
# wala sa tokens: didn
# wala sa tokens: because
# wala sa tokens: was
# negative: afraid
# wala sa tokens: was
# wala sa tokens: too
# wala sa tokens: far
# wala sa tokens: gone
# wala sa tokens: but
# neutral: clearly
# wala sa tokens: needed
# neutral: someone
# neutral: there
# wala sa tokens: for
# wala sa tokens: him
# wala sa tokens: just
# positive: hope
# wala sa tokens: finds
# wala sa tokens: the
# positive: love
# wala sa tokens: needs
# 56
# neutral: still
# wala sa tokens: have
# neutral: soft
# neutral: spot
# wala sa tokens: for
# wala sa tokens: you
# wala sa tokens: and
# neutral: always
# neutral: going
# positive: love
# wala sa tokens: you
# wala sa tokens: but
# positive: love
# neutral: means
# neutral: making
# neutral: sure
# wala sa tokens: the
# neutral: people
# wala sa tokens: you
# positive: care
# wala sa tokens: about
# wala sa tokens: are
# positive: happy
# wala sa tokens: and
# wala sa tokens: the
# positive: best
# wala sa tokens: versions
# wala sa tokens: themselves
# neutral: sometimes
# neutral: find
# wala sa tokens: myself
# neutral: wishing
# wala sa tokens: that
# wala sa tokens: the
# neutral: end
# neutral: tayo
# wala sa tokens: rin
# neutral: yung
# neutral: magkakatuluyan
# wala sa tokens: but
# neutral: whenever
# neutral: see
# wala sa tokens: you
# positive: happy
# wala sa tokens: with
# wala sa tokens: him
# wala sa tokens: just
# neutral: know
# wala sa tokens: that
# wala sa tokens: have
# neutral: accept
# wala sa tokens: that
# wala sa tokens: not
# neutral: going
# neutral: happen
# wala sa tokens: ang
# negative: hirap
# neutral: talaga
# neutral: tanggapin
# wala sa tokens: that
# neutral: never
# neutral: going
# neutral: enough
# wala sa tokens: for
# wala sa tokens: you
# wala sa tokens: but
# neutral: here
# wala sa tokens: what
# neutral: could
# wala sa tokens: have
# wala sa tokens: been
# wala sa tokens: where
# wala sa tokens: are
# wala sa tokens: now
# wala sa tokens: and
# wala sa tokens: where
# 57
# wala sa tokens: omg
# neutral: can
# neutral: also
# neutral: please
# wala sa tokens: have
# wala sa tokens: this
# neutral: revolutionary
# neutral: actual
# neutral: links
# wala sa tokens: tiny
# wala sa tokens: meets
# wala sa tokens: pickform
# wala sa tokens: tiny
# wala sa tokens: meets
# wala sa tokens: pickmenu
# 58
# neutral: believe
# neutral: school
# wala sa tokens: has
# wala sa tokens: conditioned
# wala sa tokens: perfectionists
# wala sa tokens: excelling
# wala sa tokens: not
# wala sa tokens: for
# wala sa tokens: the
# neutral: purpose
# neutral: learning
# wala sa tokens: and
# positive: improvement
# wala sa tokens: but
# wala sa tokens: from
# wala sa tokens: the
# negative: fear
# negative: failure
# wala sa tokens: and
# negative: inadequacy
# wala sa tokens: embedded
# wala sa tokens: our
# wala sa tokens: brains
# wala sa tokens: the
# wala sa tokens: smartest
# wala sa tokens: guys
# neutral: get
# wala sa tokens: rewarded
# wala sa tokens: the
# wala sa tokens: failures
# wala sa tokens: don
# neutral: graduate
# wala sa tokens: but
# wala sa tokens: aren
# wala sa tokens: just
# wala sa tokens: students
# wala sa tokens: aren
# wala sa tokens: robots
# wala sa tokens: are
# neutral: people
# wala sa tokens: are
# wala sa tokens: not
# neutral: limited
# wala sa tokens: the
# neutral: things
# wala sa tokens: that
# neutral: try
# wala sa tokens: put
# neutral: box
# wala sa tokens: all
# wala sa tokens: have
# wala sa tokens: our
# wala sa tokens: own
# neutral: form
# positive: beauty
# wala sa tokens: and
# positive: intelligence
# wala sa tokens: and
# wala sa tokens: our
# wala sa tokens: lives
# wala sa tokens: are
# wala sa tokens: about
# neutral: using
# wala sa tokens: fullest
# neutral: potential
# wala sa tokens: not
# wala sa tokens: about
# wala sa tokens: grades
# wala sa tokens: not
# wala sa tokens: about
# wala sa tokens: what
# wala sa tokens: you
# neutral: get
# wala sa tokens: but
# wala sa tokens: who
# wala sa tokens: you
# neutral: become
# wala sa tokens: you
# neutral: reading
# wala sa tokens: this
# wala sa tokens: and
# wala sa tokens: you
# neutral: going
# wala sa tokens: through
# neutral: tough
# neutral: time
# wala sa tokens: these
# neutral: final
# wala sa tokens: weeks
# neutral: remember
# wala sa tokens: that
# wala sa tokens: while
# wala sa tokens: you
# neutral: always
# wala sa tokens: your
# positive: best
# neutral: never
# neutral: think
# wala sa tokens: that
# wala sa tokens: you
# wala sa tokens: have
# neutral: something
# neutral: prove
# neutral: anyone
# wala sa tokens: that
# wala sa tokens: you
# wala sa tokens: trying
# neutral: validate
# neutral: something
# neutral: control
# wala sa tokens: what
# wala sa tokens: you
# neutral: can
# neutral: control
# neutral: existence
# wala sa tokens: precedes
# neutral: essence
# 59
# neutral: can
# neutral: please
# neutral: stop
# wala sa tokens: downplaying
# wala sa tokens: other
# wala sa tokens: courses
# neutral: management
# wala sa tokens: not
# neutral: basic
# neutral: course
# wala sa tokens: you
# wala sa tokens: have
# neutral: someone
# neutral: calling
# wala sa tokens: you
# wala sa tokens: out
# wala sa tokens: for
# wala sa tokens: having
# negative: mediocre
# wala sa tokens: grades
# wala sa tokens: but
# wala sa tokens: what
# wala sa tokens: does
# neutral: card
# wala sa tokens: with
# wala sa tokens: your
# positive: happiness
# wala sa tokens: what
# neutral: everyone
# wala sa tokens: the
# neutral: family
# neutral: smart
# wala sa tokens: does
# wala sa tokens: that
# negative: mean
# wala sa tokens: have
# neutral: also
# wala sa tokens: what
# neutral: much
# neutral: rather
# neutral: active
# neutral: orgs
# neutral: want
# wala sa tokens: with
# wala sa tokens: our
# wala sa tokens: friends
# neutral: can
# neutral: stop
# negative: judging
# neutral: one
# neutral: another
# wala sa tokens: and
# neutral: support
# wala sa tokens: each
# wala sa tokens: other
# neutral: growth
# wala sa tokens: and
# positive: happiness
# neutral: instead
# negative: damn
# 60
# neutral: charot
# positive: good
# wala sa tokens: for
# wala sa tokens: your
# neutral: eyes
# 61
# neutral: taong
# neutral: gulang
# neutral: pero
# neutral: isip
# neutral: bata
# wala sa tokens: rin
# 62
# wala sa tokens: heard
# wala sa tokens: that
# wala sa tokens: the
# neutral: aegis
# neutral: shoot
# wala sa tokens: for
# wala sa tokens: ica
# neutral: jude
# wala sa tokens: and
# neutral: grace
# wala sa tokens: are
# wala sa tokens: all
# neutral: taking
# neutral: place
# wala sa tokens: the
# wala sa tokens: same
# neutral: time
# wala sa tokens: iso
# neutral: prepare
# wala sa tokens: for
# wala sa tokens: the
# neutral: chinese
# neutral: invasion
# 63
# neutral: mood
# neutral: mood
# 64
# negative: tangina
# neutral: naman
# 65
# neutral: normal
# negative: doubt
# wala sa tokens: man
# neutral: kapag
# wala sa tokens: may
# neutral: nag
# neutral: notif
# wala sa tokens: about
# neutral: grindr
# wala sa tokens: and
# wala sa tokens: other
# negative: shit
# neutral: sabi
# neutral: niya
# neutral: hindi
# wala sa tokens: daw
# neutral: siya
# neutral: active
# neutral: pero
# wala sa tokens: why
# wala sa tokens: won
# neutral: delete
# wala sa tokens: those
# negative: fucking
# neutral: apps
# neutral: tapos
# wala sa tokens: said
# neutral: kung
# neutral: nag
# negative: ddoubt
# neutral: ibig
# neutral: sabihin
# wala sa tokens: may
# ...
# wala sa tokens: with
# neutral: something
# negative: hate
# wala sa tokens: have
# neutral: least
# neutral: common
# neutral: ground
# neutral: talk
# wala sa tokens: about
# wala sa tokens: when
# neutral: get
# wala sa tokens: the
# neutral: chance
# wala sa tokens: with
# wala sa tokens: the
# neutral: people
# wala sa tokens: that
# neutral: deem
# positive: admirable
# 848
# wala sa tokens: all
# wala sa tokens: the
# negative: sadboi
# negative: sadgorl
# wala sa tokens: posts
# wala sa tokens: about
# wala sa tokens: confessing
# wala sa tokens: the
# wala sa tokens: ones
# wala sa tokens: they
# neutral: admire
# wala sa tokens: and
# wala sa tokens: have
# wala sa tokens: failed
# neutral: least
# wala sa tokens: you
# wala sa tokens: tried
# wala sa tokens: and
# neutral: maybe
# wala sa tokens: she
# neutral: really
# wala sa tokens: isn
# wala sa tokens: the
# neutral: one
# wala sa tokens: for
# wala sa tokens: you
# wala sa tokens: but
# neutral: glad
# wala sa tokens: that
# wala sa tokens: you
# wala sa tokens: were
# neutral: able
# neutral: muster
# wala sa tokens: the
# neutral: courage
# neutral: confess
# neutral: ask
# wala sa tokens: them
# wala sa tokens: out
# neutral: believe
# positive: better
# neutral: let
# neutral: loose
# wala sa tokens: and
# neutral: let
# neutral: instead
# neutral: keeping
# wala sa tokens: and
# neutral: eventually
# neutral: never
# neutral: opening
# wala sa tokens: about
# neutral: life
# wala sa tokens: goes
# wala sa tokens: and
# neutral: keep
# wala sa tokens: loving
# 849
# wala sa tokens: ang
# neutral: solid
# wala sa tokens: lions
# neutral: orgs
# 850
# neutral: anong
# neutral: gagawin
# wala sa tokens: pag
# negative: sinisiraan
# neutral: isang
# neutral: lalaki
# neutral: dahil
# wala sa tokens: may
# neutral: gusto
# neutral: siya
# neutral: sayo
# 851
# wala sa tokens: the
# wala sa tokens: god
# neutral: king
# neutral: destroyer
# wala sa tokens: worlds
# neutral: rammus
# 852
# neutral: would
# neutral: highly
# neutral: recommend
# neutral: walking
# neutral: around
# neutral: campus
# wala sa tokens: mid
# neutral: afternoon
# wala sa tokens: ish
# wala sa tokens: while
# neutral: listening
# wala sa tokens: the
# neutral: howl
# wala sa tokens: moving
# neutral: castle
# neutral: main
# neutral: theme
# wala sa tokens: any
# neutral: studio
# neutral: ghibli
# neutral: soundtrack
# wala sa tokens: for
# wala sa tokens: that
# neutral: matter
# wala sa tokens: did
# wala sa tokens: that
# wala sa tokens: few
# neutral: days
# wala sa tokens: ago
# wala sa tokens: way
# wala sa tokens: bel
# wala sa tokens: from
# wala sa tokens: covered
# wala sa tokens: courts
# wala sa tokens: and
# wala sa tokens: with
# wala sa tokens: that
# neutral: being
# wala sa tokens: the
# neutral: accompaniment
# wala sa tokens: the
# neutral: breeze
# wala sa tokens: and
# wala sa tokens: the
# wala sa tokens: not
# wala sa tokens: too
# negative: harsh
# neutral: sunlight
# wala sa tokens: made
# neutral: forget
# wala sa tokens: had
# wala sa tokens: problems
# wala sa tokens: and
# wala sa tokens: deadlines
# wala sa tokens: for
# neutral: least
# neutral: minutes
# wala sa tokens: ang
# positive: ganda
# neutral: feeling
# positive: thanks
# wala sa tokens: joe
# neutral: hisashi
# 853
# neutral: dami
# neutral: niyong
# neutral: oras
# wala sa tokens: mag
# neutral: facebook
# neutral: pahingi
# neutral: naman
# 854
# neutral: admu
# neutral: study
# neutral: buddy
# neutral: hellooo
# wala sa tokens: again
# wala sa tokens: the
# neutral: original
# neutral: post
# neutral: admufreedomwall
# wala sa tokens: had
# wala sa tokens: more
# wala sa tokens: than
# neutral: enough
# positive: favorable
# wala sa tokens: responses
# wala sa tokens: and
# neutral: even
# wala sa tokens: some
# wala sa tokens: from
# neutral: despite
# wala sa tokens: the
# neutral: name
# neutral: admu
# neutral: study
# neutral: buddy
# wala sa tokens: will
# neutral: also
# neutral: open
# wala sa tokens: non
# neutral: ateneans
# wala sa tokens: who
# wala sa tokens: are
# neutral: studying
# neutral: katip
# neutral: ensure
# wala sa tokens: that
# wala sa tokens: only
# wala sa tokens: students
# wala sa tokens: from
# neutral: katip
# wala sa tokens: universities
# wala sa tokens: are
# wala sa tokens: the
# neutral: sheet
# neutral: require
# wala sa tokens: submissions
# neutral: use
# wala sa tokens: their
# neutral: school
# neutral: email
# wala sa tokens: addresses
# wala sa tokens: how
# wala sa tokens: does
# wala sa tokens: this
# neutral: work
# neutral: first
# neutral: step
# neutral: fill
# wala sa tokens: out
# wala sa tokens: this
# neutral: form
# wala sa tokens: https
# wala sa tokens: goo
# wala sa tokens: forms
# wala sa tokens: uueikcb
# wala sa tokens: hswkaf
# neutral: second
# neutral: step
# neutral: check
# wala sa tokens: out
# wala sa tokens: the
# neutral: gsheet
# wala sa tokens: and
# neutral: look
# wala sa tokens: for
# neutral: someone
# neutral: study
# wala sa tokens: with
# wala sa tokens: https
# wala sa tokens: goo
# wala sa tokens: nqukyq
# neutral: third
# neutral: step
# neutral: email
# wala sa tokens: the
# neutral: person
# wala sa tokens: you
# neutral: wish
# neutral: study
# wala sa tokens: with
# neutral: polite
# neutral: fourth
# neutral: step
# neutral: wait
# wala sa tokens: for
# wala sa tokens: the
# neutral: person
# neutral: reply
# wala sa tokens: for
# neutral: someone
# neutral: email
# wala sa tokens: you
# wala sa tokens: these
# wala sa tokens: are
# wala sa tokens: only
# wala sa tokens: for
# neutral: september
# neutral: october
# neutral: another
# neutral: form
# wala sa tokens: and
# neutral: sheet
# wala sa tokens: will
# wala sa tokens: uploaded
# neutral: there
# neutral: still
# neutral: demand
# wala sa tokens: for
# neutral: something
# neutral: like
# wala sa tokens: this
# neutral: would
# neutral: greatly
# neutral: appreciate
# wala sa tokens: you
# neutral: could
# neutral: share
# wala sa tokens: this
# wala sa tokens: with
# wala sa tokens: your
# wala sa tokens: friends
# wala sa tokens: and
# neutral: help
# neutral: spread
# wala sa tokens: the
# neutral: word
# wala sa tokens: you
# neutral: know
# wala sa tokens: what
# wala sa tokens: they
# neutral: say
# wala sa tokens: the
# wala sa tokens: more
# wala sa tokens: the
# wala sa tokens: merrier
# 855
# neutral: show
# positive: love
# wala sa tokens: your
# neutral: homies
# 856
# neutral: try
# neutral: resist
# wala sa tokens: kim
# neutral: jisoo
# neutral: dare
# wala sa tokens: you
# 857
# wala sa tokens: who
# wala sa tokens: the
# neutral: super
# positive: cool
# wala sa tokens: cop
# neutral: always
# wala sa tokens: gets
# wala sa tokens: the
# wala sa tokens: bad
# neutral: guy
# neutral: donut
# neutral: boy
# wala sa tokens: that
# neutral: yeah
# neutral: bring
# positive: delicious
# neutral: assortment
# positive: sweet
# positive: delight
# neutral: donut
# neutral: boy
# wala sa tokens: got
# neutral: creamy
# neutral: filling
# 858
# neutral: want
# neutral: build
# neutral: parking
# neutral: building
# neutral: ateneo
# 859
# neutral: like
# wala sa tokens: when
# neutral: boyfriend
# wala sa tokens: asks
# neutral: stuff
# wala sa tokens: for
# wala sa tokens: him
# neutral: can
# neutral: tease
# neutral: back
# wala sa tokens: about
# wala sa tokens: his
# positive: love
# neutral: warcraft
# neutral: saying
# wala sa tokens: yes
# neutral: milord
# wala sa tokens: jobs
# wala sa tokens: done
# wala sa tokens: what
# 860
# wala sa tokens: why
# neutral: would
# neutral: one
# negative: despair
# wala sa tokens: they
# wala sa tokens: are
# neutral: machiavellian
# 861
# neutral: tag
# positive: cute
# neutral: single
# neutral: means
# 862
# neutral: want
# wala sa tokens: stepped
# 863
# neutral: please
# neutral: give
# neutral: manga
# neutral: webcomic
# wala sa tokens: suggestions
# wala sa tokens: plz
# wala sa tokens: uwu
# 864
# wala sa tokens: oof
# 865
# neutral: eagle
# neutral: even
# wala sa tokens: the
# neutral: heart
# neutral: regis
# neutral: iskos
# neutral: can
# neutral: still
# neutral: feel
# negative: fear
# neutral: spear
# neutral: falls
# wala sa tokens: from
# wala sa tokens: the
# wala sa tokens: sky
# wala sa tokens: into
# wala sa tokens: the
# neutral: regis
# neutral: building
# neutral: isko
# wala sa tokens: old
# neutral: enemy
# wala sa tokens: you
# neutral: cannot
# neutral: hide
# wala sa tokens: from
# neutral: matter
# wala sa tokens: what
# neutral: form
# wala sa tokens: you
# neutral: choose
# neutral: wear
# neutral: let
# wala sa tokens: your
# positive: true
# neutral: self
# wala sa tokens: revealed
# neutral: elitista
# neutral: elitista
# wala sa tokens: our
# neutral: long
# wala sa tokens: war
# wala sa tokens: ends
# wala sa tokens: day
# neutral: isko
# wala sa tokens: stabs
# neutral: isko
# neutral: isko
# neutral: elitista
# neutral: take
# neutral: one
# neutral: last
# neutral: look
# wala sa tokens: your
# neutral: shining
# neutral: regis
# neutral: isko
# wala sa tokens: for
# neutral: soon
# neutral: nothing
# neutral: shall
# neutral: remain
# wala sa tokens: but
# wala sa tokens: your
# neutral: area
# wala sa tokens: tosses
# neutral: isko
# neutral: aside
# wala sa tokens: and
# wala sa tokens: walks
# wala sa tokens: into
# neutral: coco
# wala sa tokens: for
# wala sa tokens: some
# wala sa tokens: tea
# 866
# wala sa tokens: have
# wala sa tokens: this
# neutral: massive
# neutral: fetish
# wala sa tokens: for
# neutral: tall
# wala sa tokens: girls
# wala sa tokens: and
# neutral: short
# neutral: guy
# neutral: comparison
# neutral: secretly
# neutral: imagine
# wala sa tokens: that
# neutral: gimli
# wala sa tokens: son
# neutral: gloin
# wala sa tokens: and
# wala sa tokens: the
# neutral: girl
# neutral: galadriel
# 867
# wala sa tokens: you
# neutral: senior
# neutral: try
# neutral: going
# neutral: admu
# neutral: early
# wala sa tokens: the
# neutral: morning
# wala sa tokens: and
# wala sa tokens: just
# neutral: sit
# neutral: somewhere
# wala sa tokens: yourself
# wala sa tokens: and
# neutral: look
# neutral: around
# wala sa tokens: that
# neutral: moment
# positive: peacefulness
# wala sa tokens: you
# neutral: get
# wala sa tokens: flashbacks
# wala sa tokens: all
# wala sa tokens: the
# wala sa tokens: memories
# wala sa tokens: you
# wala sa tokens: made
# wala sa tokens: this
# neutral: place
# wala sa tokens: and
# wala sa tokens: you
# neutral: think
# wala sa tokens: about
# wala sa tokens: how
# neutral: much
# wala sa tokens: you
# neutral: miss
# wala sa tokens: them
# wala sa tokens: once
# wala sa tokens: you
# neutral: leave
# wala sa tokens: makes
# wala sa tokens: you
# negative: sad
# wala sa tokens: but
# neutral: also
# wala sa tokens: makes
# wala sa tokens: you
# neutral: want
# neutral: cherish
# wala sa tokens: the
# neutral: time
# wala sa tokens: you
# wala sa tokens: have
# neutral: left
# neutral: here
# wala sa tokens: you
# neutral: think
# wala sa tokens: the
# neutral: people
# wala sa tokens: you
# neutral: want
# wala sa tokens: have
# neutral: lunch
# wala sa tokens: with
# wala sa tokens: org
# wala sa tokens: events
# wala sa tokens: you
# wala sa tokens: wouldn
# neutral: want
# neutral: miss
# wala sa tokens: and
# wala sa tokens: after
# wala sa tokens: that
# neutral: guess
# wala sa tokens: all
# wala sa tokens: that
# neutral: left
# wala sa tokens: and
# neutral: make
# wala sa tokens: the
# wala sa tokens: most
# wala sa tokens: out
# 868
# neutral: note
# neutral: ateneans
# wala sa tokens: don
# neutral: agree
# wala sa tokens: with
# wala sa tokens: the
# neutral: many
# wala sa tokens: students
# neutral: being
# neutral: regis
# wala sa tokens: are
# negative: annoying
# neutral: post
# wala sa tokens: but
# wala sa tokens: not
# neutral: here
# wala sa tokens: for
# wala sa tokens: that
# wala sa tokens: this
# neutral: university
# neutral: rank
# neutral: discussion
# neutral: post
# wala sa tokens: the
# neutral: tweet
# wala sa tokens: that
# wala sa tokens: became
# neutral: popular
# wala sa tokens: said
# wala sa tokens: that
# neutral: ateneo
# wala sa tokens: was
# wala sa tokens: just
# neutral: rate
# neutral: university
# wala sa tokens: compared
# wala sa tokens: https
# neutral: mobile
# neutral: twitter
# wala sa tokens: com
# wala sa tokens: piodu
# neutral: status
# neutral: know
# neutral: joke
# neutral: tweet
# wala sa tokens: but
# wala sa tokens: reminded
# wala sa tokens: that
# wala sa tokens: age
# wala sa tokens: old
# neutral: discussion
# neutral: university
# wala sa tokens: rankings
# wala sa tokens: the
# neutral: end
# wala sa tokens: the
# neutral: general
# neutral: rank
# wala sa tokens: your
# neutral: university
# wala sa tokens: far
# wala sa tokens: less
# neutral: important
# wala sa tokens: than
# wala sa tokens: the
# neutral: rank
# wala sa tokens: your
# neutral: specific
# neutral: course
# neutral: minority
# wala sa tokens: students
# neutral: like
# neutral: brag
# neutral: towards
# neutral: ateneans
# neutral: likewise
# neutral: minority
# neutral: ateneans
# neutral: brag
# wala sa tokens: against
# neutral: dlsu
# wala sa tokens: and
# wala sa tokens: but
# wala sa tokens: the
# neutral: university
# wala sa tokens: rankings
# wala sa tokens: are
# negative: meaningless
# wala sa tokens: when
# wala sa tokens: you
# neutral: check
# wala sa tokens: the
# neutral: board
# neutral: exam
# neutral: passing
# neutral: rate
# wala sa tokens: your
# neutral: specific
# neutral: course
# wala sa tokens: the
# neutral: top
# neutral: medical
# wala sa tokens: schools
# wala sa tokens: the
# neutral: country
# wala sa tokens: aren
# neutral: even
# wala sa tokens: from
# wala sa tokens: the
# neutral: big
# neutral: course
# neutral: rank
# wala sa tokens: lot
# wala sa tokens: more
# neutral: important
# wala sa tokens: than
# neutral: school
# neutral: rank
# neutral: ofcourse
# wala sa tokens: don
# neutral: forget
# wala sa tokens: about
# neutral: mental
# neutral: health
# neutral: though
# 869
# neutral: swear
# neutral: doods
# wala sa tokens: sao
# wala sa tokens: gonna
# wala sa tokens: the
# positive: best
# neutral: anime
# wala sa tokens: the
# neutral: end
# wala sa tokens: the
# neutral: season
# 870
# neutral: tag
# wala sa tokens: your
# neutral: crush
# neutral: crush
# 871
# neutral: feel
# negative: helpless
# neutral: right
# wala sa tokens: now
# negative: hate
# neutral: college
# wala sa tokens: and
# wala sa tokens: the
# neutral: people
# neutral: really
# wala sa tokens: don
# neutral: know
# wala sa tokens: what
# wala sa tokens: should
# wala sa tokens: have
# positive: wonderful
# neutral: girlfriend
# wala sa tokens: and
# neutral: still
# neutral: feel
# negative: unamused
# neutral: times
# wala sa tokens: don
# wala sa tokens: have
# wala sa tokens: friends
# wala sa tokens: nor
# wala sa tokens: have
# neutral: family
# neutral: home
# wala sa tokens: this
# neutral: rate
# neutral: feel
# neutral: like
# neutral: everyone
# neutral: leaving
# wala sa tokens: this
# wala sa tokens: why
# negative: hate
# neutral: people
# neutral: try
# negative: hard
# neutral: make
# wala sa tokens: friends
# wala sa tokens: and
# neutral: hide
# wala sa tokens: imperfections
# neutral: know
# wala sa tokens: shouldn
# neutral: entertain
# wala sa tokens: the
# neutral: social
# neutral: aspect
# wala sa tokens: what
# neutral: society
# wala sa tokens: suggests
# neutral: towards
# wala sa tokens: how
# neutral: things
# wala sa tokens: the
# neutral: world
# wala sa tokens: should
# wala sa tokens: but
# neutral: find
# wala sa tokens: myself
# wala sa tokens: trying
# neutral: someone
# wala sa tokens: not
# wala sa tokens: for
# wala sa tokens: the
# neutral: sake
# wala sa tokens: having
# neutral: people
# neutral: stay
# wala sa tokens: with
# wala sa tokens: and
# neutral: feel
# wala sa tokens: loved
# wala sa tokens: then
# neutral: there
# wala sa tokens: are
# neutral: times
# neutral: people
# wala sa tokens: just
# neutral: whisper
# neutral: around
# neutral: like
# neutral: can
# neutral: part
# wala sa tokens: the
# neutral: conversation
# 872
# neutral: really
# neutral: want
# neutral: break
# neutral: diet
# wala sa tokens: and
# neutral: get
# wala sa tokens: the
# neutral: piece
# neutral: chicken
# wala sa tokens: nuggets
# wala sa tokens: from
# neutral: mcdo
# neutral: please
# neutral: lend
# wala sa tokens: your
# neutral: strength
# neutral: calling
# neutral: names
# wala sa tokens: and
# wala sa tokens: insulting
# wala sa tokens: don
# negative: worry
# neutral: masochist
# positive: love
# neutral: being
# wala sa tokens: degraded
# neutral: make
# negative: hurt
# wala sa tokens: mommies
# wala sa tokens: and
# wala sa tokens: daddies
# neutral: help
# neutral: keep
# neutral: diet
# positive: thank
# wala sa tokens: you
# 873
# wala sa tokens: when
# neutral: play
# neutral: big
# neutral: fish
# wala sa tokens: but
# neutral: want
# neutral: make
# neutral: landi
# wala sa tokens: rin
# 874
# neutral: try
# neutral: try
# neutral: try
# neutral: follow
# wala sa tokens: the
# wala sa tokens: rules
# neutral: break
# neutral: every
# neutral: one
# wala sa tokens: them
# wala sa tokens: with
# wala sa tokens: girls
# neutral: like
# wala sa tokens: you
# wala sa tokens: doing
# wala sa tokens: what
# neutral: always
# neutral: yeah
# neutral: crossing
# neutral: every
# neutral: line
# neutral: get
# wala sa tokens: girls
# neutral: like
# wala sa tokens: you
# wala sa tokens: tripping
# wala sa tokens: freaking
# wala sa tokens: falling
# wala sa tokens: over
# wala sa tokens: girls
# neutral: like
# wala sa tokens: you
